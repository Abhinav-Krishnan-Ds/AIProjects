# %%
import cv2
import mediapipe as mp
import time
import math as math


class HandTrackingDynamic:
    def __init__(self, mode=False, maxHands=2, detectionCon=0.5, trackCon=0.5):
        self.__mode__   =  mode
        self.__maxHands__   =  maxHands
        self.__detectionCon__   =   detectionCon
        self.__trackCon__   =   trackCon
        self.handsMp = mp.solutions.hands
        self.hands = self.handsMp.Hands()
        self.mpDraw= mp.solutions.drawing_utils
        self.tipIds = [4, 8, 12, 16, 20]

    def findFingers(self, frame, draw=True):
        imgRGB = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        self.results = self.hands.process(imgRGB)  
        if self.results.multi_hand_landmarks: 
            for handLms in self.results.multi_hand_landmarks:
                if draw:
                    self.mpDraw.draw_landmarks(frame, handLms,self.handsMp.HAND_CONNECTIONS)

        return frame

    def findPosition( self, frame, handNo=0, draw=True):
        xList =[]
        yList =[]
        bbox = []
        self.lmsList=[]
        if self.results.multi_hand_landmarks:
            myHand = self.results.multi_hand_landmarks[handNo]
            for id, lm in enumerate(myHand.landmark):
            
                h, w, c = frame.shape
                cx, cy = int(lm.x * w), int(lm.y * h)
                xList.append(cx)
                yList.append(cy)
                self.lmsList.append([id, cx, cy])
                if draw:
                    cv2.circle(frame,  (cx, cy), 5, (255, 0, 255), cv2.FILLED)

            xmin, xmax = min(xList), max(xList)
            ymin, ymax = min(yList), max(yList)
            bbox = xmin, ymin, xmax, ymax
            print( "Hands Keypoint")
            print(bbox)
            if draw:
                cv2.rectangle(frame, (xmin - 20, ymin - 20),(xmax + 20, ymax + 20),
                               (0, 255 , 0) , 2)

        return self.lmsList, bbox
    
    def findFingerUp(self):
         fingers=[]

         if self.lmsList[self.tipIds[0]][1] > self.lmsList[self.tipIds[0]-1][1]:
              fingers.append(1)
         else:
              fingers.append(0)

         for id in range(1, 5):            
              if self.lmsList[self.tipIds[id]][2] < self.lmsList[self.tipIds[id]-2][2]:
                   fingers.append(1)
              else:
                   fingers.append(0)
        
         return fingers

    def findDistance(self, p1, p2, frame, draw= True, r=15, t=3):
         
        x1 , y1 = self.lmsList[p1][1:]
        x2, y2 = self.lmsList[p2][1:]
        cx , cy = (x1+x2)//2 , (y1 + y2)//2

        if draw:
              cv2.line(frame,(x1, y1),(x2,y2) ,(255,0,255), t)
              cv2.circle(frame,(x1,y1),r,(255,0,255),cv2.FILLED)
              cv2.circle(frame,(x2,y2),r, (255,0,0),cv2.FILLED)
              cv2.circle(frame,(cx,cy), r,(0,0.255),cv2.FILLED)
        len= math.hypot(x2-x1,y2-y1)

        return len, frame , [x1, y1, x2, y2, cx, cy]

def main():
        
        ctime=0
        ptime=0
        cap = cv2.VideoCapture(0)
        detector = HandTrackingDynamic()
        cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
        cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
        if not cap.isOpened():
            print("Cannot open camera")
            exit()

        while True:
            ret, frame = cap.read()

            frame = detector.findFingers(frame)
            lmsList = detector.findPosition(frame)
            # if len(lmsList)!=0:
                #print(lmsList[0])

            ctime = time.time()
            fps =1/(ctime-ptime)
            ptime = ctime

            cv2.putText(frame, str(int(fps)), (10,70), cv2.FONT_HERSHEY_PLAIN,3,(255,0,255),3)
 
    #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            cv2.imshow('frame', frame)
            cv2.waitKey(1)


                
if __name__ == "__main__":
            main()
# Out:
# 2024-11-08 15:28:02.340558: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-08 15:28:02.564776: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-08 15:28:02.564899: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-08 15:28:02.593006: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-08 15:28:02.652529: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-08 15:28:04.534319: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731059887.112415   24189 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1731059887.154405   24282 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.01), renderer: NVIDIA GeForce RTX 3050 Laptop GPU/PCIe/SSE2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# /home/abhinav/.local/lib/python3.10/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Hands Keypoint
# (365, 356, 441, 418)
# Hands Keypoint
# (370, 349, 447, 423)
# Hands Keypoint
# (370, 350, 448, 425)
# Hands Keypoint
# (535, 408, 606, 472)
# Hands Keypoint
# (535, 402, 601, 468)
# Hands Keypoint
# (536, 405, 605, 469)
# Hands Keypoint
# (535, 409, 609, 474)
# Hands Keypoint
# (534, 404, 606, 474)
# Hands Keypoint
# (533, 402, 604, 472)
# Hands Keypoint
# (535, 404, 607, 474)
# Hands Keypoint
# (533, 403, 609, 473)
# Hands Keypoint
# (535, 403, 608, 475)
# Hands Keypoint
# (534, 403, 608, 474)
# Hands Keypoint
# (535, 401, 610, 475)
# Hands Keypoint
# (535, 400, 610, 477)
# Hands Keypoint
# (534, 400, 612, 476)
# Hands Keypoint
# (534, 400, 611, 478)
# Hands Keypoint
# (532, 396, 612, 475)
# Hands Keypoint
# (530, 394, 614, 470)
# Hands Keypoint
# (525, 388, 601, 461)
# Hands Keypoint
# (518, 381, 606, 451)
# Hands Keypoint
# (505, 375, 596, 437)
# Hands Keypoint
# (493, 370, 586, 426)
# Hands Keypoint
# (475, 370, 563, 416)
# Hands Keypoint
# (465, 364, 558, 413)
# Hands Keypoint
# (454, 358, 546, 403)
# Hands Keypoint
# (447, 355, 539, 399)
# Hands Keypoint
# (438, 356, 531, 397)
# Hands Keypoint
# (431, 356, 519, 394)
# Hands Keypoint
# (425, 355, 508, 393)
# Hands Keypoint
# (423, 361, 509, 395)
# Hands Keypoint
# (433, 362, 522, 400)
# Hands Keypoint
# (378, 374, 472, 417)
# Hands Keypoint
# (456, 357, 557, 403)
# Hands Keypoint
# (473, 353, 556, 398)
# Hands Keypoint
# (501, 277, 598, 398)
# Hands Keypoint
# (437, 271, 527, 390)
# Hands Keypoint
# (433, 269, 524, 389)
# Hands Keypoint
# (433, 269, 523, 390)
# Hands Keypoint
# (434, 271, 525, 391)
# Hands Keypoint
# (434, 272, 525, 391)
# Hands Keypoint
# (434, 272, 525, 393)
# Hands Keypoint
# (435, 272, 526, 392)
# Hands Keypoint
# (437, 271, 527, 392)
# Hands Keypoint
# (438, 273, 525, 393)
# Hands Keypoint
# (439, 275, 522, 392)
# Hands Keypoint
# (438, 284, 518, 395)
# Hands Keypoint
# (436, 299, 509, 394)
# Hands Keypoint
# (434, 304, 504, 392)
# Hands Keypoint
# (436, 307, 502, 392)
# Hands Keypoint
# (440, 311, 502, 395)
# Hands Keypoint
# (443, 312, 503, 395)
# Hands Keypoint
# (446, 313, 508, 394)
# Hands Keypoint
# (450, 314, 511, 392)
# Hands Keypoint
# (453, 315, 514, 392)
# Hands Keypoint
# (455, 317, 517, 393)
# Hands Keypoint
# (456, 321, 519, 396)
# Hands Keypoint
# (458, 324, 522, 397)
# Hands Keypoint
# (460, 326, 524, 398)
# Hands Keypoint
# (463, 327, 526, 399)
# Hands Keypoint
# (465, 328, 528, 399)
# Hands Keypoint
# (468, 331, 531, 400)
# Hands Keypoint
# (472, 332, 534, 402)
# Hands Keypoint
# (473, 335, 535, 403)
# Hands Keypoint
# (473, 335, 536, 403)
# Hands Keypoint
# (474, 336, 536, 404)
# Hands Keypoint
# (473, 336, 537, 405)
# Hands Keypoint
# (475, 337, 538, 405)
# Hands Keypoint
# (476, 339, 540, 406)
# Hands Keypoint
# (477, 339, 541, 407)
# Hands Keypoint
# (478, 340, 540, 408)
# Hands Keypoint
# (478, 338, 541, 407)
# Hands Keypoint
# (477, 339, 541, 407)
# Hands Keypoint
# (478, 338, 541, 407)
# Hands Keypoint
# (477, 337, 540, 407)
# Hands Keypoint
# (476, 335, 539, 406)
# Hands Keypoint
# (476, 335, 538, 406)
# Hands Keypoint
# (476, 334, 538, 405)
# Hands Keypoint
# (476, 334, 537, 406)
# Hands Keypoint
# (476, 333, 538, 405)
# Hands Keypoint
# (476, 332, 538, 406)
# Hands Keypoint
# (475, 332, 537, 407)
# Hands Keypoint
# (473, 331, 536, 408)
# Hands Keypoint
# (470, 329, 535, 407)
# Hands Keypoint
# (465, 328, 530, 406)
# Hands Keypoint
# (454, 312, 524, 400)
# Hands Keypoint
# (447, 295, 522, 394)
# Hands Keypoint
# (439, 281, 517, 386)
# Hands Keypoint
# (428, 265, 506, 375)
# Hands Keypoint
# (413, 248, 498, 365)
# Hands Keypoint
# (393, 222, 485, 346)
# Hands Keypoint
# (388, 212, 481, 338)
# Hands Keypoint
# (384, 203, 480, 333)
# Hands Keypoint
# (384, 198, 480, 329)
# Hands Keypoint
# (383, 194, 480, 326)
# Hands Keypoint
# (381, 189, 480, 325)
# Hands Keypoint
# (382, 189, 480, 325)
# Hands Keypoint
# (382, 190, 482, 326)
# Hands Keypoint
# (383, 190, 483, 327)
# Hands Keypoint
# (385, 190, 484, 328)
# Hands Keypoint
# (387, 190, 486, 327)
# Hands Keypoint
# (389, 191, 487, 327)
# Hands Keypoint
# (390, 191, 489, 326)
# Hands Keypoint
# (392, 191, 490, 326)
# Hands Keypoint
# (394, 192, 490, 327)
# Hands Keypoint
# (395, 192, 490, 326)
# Hands Keypoint
# (396, 193, 489, 327)
# Hands Keypoint
# (396, 193, 490, 326)
# Hands Keypoint
# (399, 195, 491, 327)
# Hands Keypoint
# (402, 197, 493, 329)
# Hands Keypoint
# (410, 211, 495, 332)
# Hands Keypoint
# (415, 223, 496, 332)
# Hands Keypoint
# (418, 229, 498, 331)
# Hands Keypoint
# (423, 233, 501, 331)
# Hands Keypoint
# (427, 235, 504, 330)
# Hands Keypoint
# (430, 237, 506, 330)
# Hands Keypoint
# (434, 238, 506, 329)
# Hands Keypoint
# (437, 242, 506, 329)
# Hands Keypoint
# (439, 251, 503, 334)
# Hands Keypoint
# (440, 254, 505, 334)
# Hands Keypoint
# (442, 258, 507, 336)
# Hands Keypoint
# (449, 263, 512, 337)
# Hands Keypoint
# (453, 265, 516, 340)
# Hands Keypoint
# (457, 270, 519, 343)
# Hands Keypoint
# (459, 274, 522, 348)
# Hands Keypoint
# (461, 286, 525, 355)
# Hands Keypoint
# (464, 290, 527, 358)
# Hands Keypoint
# (468, 293, 533, 360)
# Hands Keypoint
# (472, 295, 534, 363)
# Hands Keypoint
# (475, 298, 538, 366)
# Hands Keypoint
# (480, 303, 542, 371)
# Hands Keypoint
# (486, 310, 549, 374)
# Hands Keypoint
# (494, 314, 557, 378)
# Hands Keypoint
# (500, 316, 565, 380)
# Hands Keypoint
# (506, 318, 572, 381)
# Hands Keypoint
# (513, 317, 575, 381)
# Hands Keypoint
# (519, 313, 580, 378)
# Hands Keypoint
# (327, 226, 361, 299)
# Hands Keypoint
# (328, 234, 361, 303)
# Hands Keypoint
# (325, 234, 360, 306)
# Hands Keypoint
# (324, 232, 368, 307)
# Hands Keypoint
# (322, 252, 361, 318)
# Hands Keypoint
# (465, 290, 526, 358)
# Hands Keypoint
# (454, 289, 514, 358)
# Hands Keypoint
# (444, 285, 503, 355)
# Hands Keypoint
# (432, 284, 494, 353)
# Hands Keypoint
# (423, 285, 483, 355)
# Hands Keypoint
# (416, 284, 476, 356)
# Hands Keypoint
# (404, 285, 465, 356)
# Hands Keypoint
# (400, 287, 460, 357)
# Hands Keypoint
# (512, 230, 578, 302)
# Hands Keypoint
# (500, 232, 571, 303)
# Hands Keypoint
# (489, 235, 561, 307)
# Hands Keypoint
# (486, 237, 554, 308)
# Hands Keypoint
# (481, 239, 549, 308)
# Hands Keypoint
# (471, 242, 540, 312)
# Hands Keypoint
# (464, 245, 534, 315)
# Hands Keypoint
# (462, 247, 530, 318)
# Hands Keypoint
# (461, 250, 529, 322)
# Hands Keypoint
# (459, 251, 529, 324)
# Hands Keypoint
# (454, 249, 531, 327)
# Hands Keypoint
# (447, 212, 535, 331)
# Hands Keypoint
# (443, 210, 541, 334)
# Hands Keypoint
# (444, 213, 545, 338)
# Hands Keypoint
# (446, 216, 545, 341)
# Hands Keypoint
# (445, 217, 547, 341)
# Hands Keypoint
# (446, 219, 548, 342)
# Hands Keypoint
# (445, 219, 550, 342)
# Hands Keypoint
# (446, 219, 551, 342)
# Hands Keypoint
# (448, 220, 553, 342)
# Hands Keypoint
# (448, 220, 554, 342)
# Hands Keypoint
# (449, 221, 555, 342)
# Hands Keypoint
# (450, 221, 556, 342)
# Hands Keypoint
# (451, 220, 556, 342)
# Hands Keypoint
# (452, 220, 556, 340)
# Hands Keypoint
# (453, 220, 556, 340)
# Hands Keypoint
# (455, 219, 555, 340)
# Hands Keypoint
# (458, 219, 554, 339)
# Hands Keypoint
# (461, 221, 554, 340)
# Hands Keypoint
# (467, 225, 554, 338)
# Hands Keypoint
# (478, 241, 558, 338)
# Hands Keypoint
# (482, 242, 559, 336)
# Hands Keypoint
# (482, 244, 561, 336)
# Hands Keypoint
# (483, 244, 562, 335)
# Hands Keypoint
# (484, 245, 563, 334)
# Hands Keypoint
# (485, 244, 564, 333)
# Hands Keypoint
# (487, 242, 566, 333)
# Hands Keypoint
# (487, 238, 566, 332)
# Hands Keypoint
# (488, 229, 567, 329)
# Hands Keypoint
# (489, 214, 569, 322)
# Hands Keypoint
# (494, 200, 575, 313)
# Hands Keypoint
# (500, 185, 585, 300)
# Hands Keypoint
# (504, 183, 588, 296)
# Hands Keypoint
# (506, 182, 591, 293)
# Hands Keypoint
# (510, 180, 596, 289)
# Hands Keypoint
# (513, 177, 601, 285)
# Hands Keypoint
# (515, 175, 604, 283)
# Hands Keypoint
# (517, 176, 607, 283)
# Hands Keypoint
# (518, 178, 608, 285)
# Hands Keypoint
# (517, 184, 608, 290)
# Hands Keypoint
# (516, 190, 608, 297)
# Hands Keypoint
# (516, 195, 608, 307)
# Hands Keypoint
# (515, 201, 608, 314)
# Hands Keypoint
# (516, 210, 608, 328)
# Hands Keypoint
# (515, 214, 609, 333)
# Hands Keypoint
# (513, 216, 609, 338)
# Hands Keypoint
# (514, 218, 608, 341)
# Hands Keypoint
# (514, 219, 609, 344)
# Hands Keypoint
# (515, 220, 609, 346)
# Hands Keypoint
# (516, 220, 609, 346)
# Hands Keypoint
# (517, 221, 610, 348)
# Hands Keypoint
# (516, 223, 610, 351)
# Hands Keypoint
# (517, 224, 610, 354)
# Hands Keypoint
# (517, 226, 610, 354)
# Hands Keypoint
# (517, 226, 611, 355)
# Hands Keypoint
# (516, 226, 611, 356)
# Hands Keypoint
# (517, 227, 612, 355)
# Hands Keypoint
# (518, 226, 613, 356)
# Hands Keypoint
# (518, 226, 613, 356)
# Hands Keypoint
# (519, 226, 615, 356)
# Hands Keypoint
# (520, 225, 616, 356)
# Hands Keypoint
# (521, 223, 613, 354)
# Hands Keypoint
# (522, 223, 611, 354)
# Hands Keypoint
# (523, 222, 612, 353)
# Hands Keypoint
# (523, 221, 615, 350)
# Hands Keypoint
# (522, 219, 619, 350)
# Hands Keypoint
# (524, 219, 619, 350)
# Hands Keypoint
# (526, 219, 621, 348)
# Hands Keypoint
# (527, 220, 622, 348)
# Hands Keypoint
# (526, 220, 623, 348)
# Hands Keypoint
# (527, 221, 625, 348)
# Hands Keypoint
# (526, 221, 625, 348)
# Hands Keypoint
# (527, 221, 625, 347)
# Hands Keypoint
# (527, 221, 626, 347)
# Hands Keypoint
# (527, 221, 627, 347)
# Hands Keypoint
# (528, 223, 629, 347)
# Hands Keypoint
# (530, 226, 632, 350)
# Hands Keypoint
# (531, 225, 633, 351)
# Hands Keypoint
# (532, 225, 633, 352)
# Hands Keypoint
# (532, 225, 634, 353)
# Hands Keypoint
# (533, 226, 637, 353)
# Hands Keypoint
# (535, 227, 638, 355)
# Hands Keypoint
# (536, 228, 641, 356)
# Hands Keypoint
# (539, 228, 641, 356)
# Hands Keypoint
# (541, 228, 645, 358)
# Hands Keypoint
# (543, 227, 645, 359)
# Hands Keypoint
# (545, 226, 647, 360)
# Hands Keypoint
# (547, 225, 652, 362)
# Hands Keypoint
# (549, 225, 651, 362)
# Hands Keypoint
# (552, 226, 652, 362)
# Hands Keypoint
# (553, 227, 656, 363)
# Hands Keypoint
# (556, 229, 655, 364)
# Hands Keypoint
# (557, 230, 661, 365)
# Hands Keypoint
# (560, 233, 662, 368)
# Hands Keypoint
# (562, 235, 659, 370)
# Hands Keypoint
# (563, 237, 660, 373)
# Hands Keypoint
# (565, 241, 655, 377)
# Hands Keypoint
# (569, 245, 657, 381)
# Hands Keypoint
# (571, 248, 665, 386)
# Hands Keypoint
# (572, 252, 667, 391)
# Hands Keypoint
# (575, 255, 665, 393)
# Hands Keypoint
# (578, 256, 669, 393)
# Hands Keypoint
# (581, 257, 684, 392)
# Hands Keypoint
# (581, 257, 676, 393)
# Hands Keypoint
# (582, 258, 674, 394)
# Hands Keypoint
# (579, 262, 675, 395)
# Hands Keypoint
# (580, 265, 668, 397)
# Hands Keypoint
# (579, 267, 665, 397)
# Hands Keypoint
# (581, 267, 665, 394)
# Hands Keypoint
# (583, 267, 671, 393)
# Hands Keypoint
# (586, 266, 663, 391)
# Hands Keypoint
# (586, 266, 663, 390)
# Hands Keypoint
# (590, 265, 671, 389)
# Hands Keypoint
# (593, 264, 675, 387)
# Hands Keypoint
# (596, 264, 678, 386)
# Hands Keypoint
# (597, 270, 674, 384)
# Hands Keypoint
# (598, 270, 678, 384)
# Hands Keypoint
# (598, 271, 668, 382)
# Hands Keypoint
# (598, 270, 672, 379)
# Hands Keypoint
# (597, 269, 678, 380)
# Hands Keypoint
# (592, 270, 669, 380)
# Hands Keypoint
# (578, 252, 670, 375)
# Hands Keypoint
# (569, 248, 665, 373)
# Hands Keypoint
# (554, 245, 656, 372)
# Hands Keypoint
# (545, 243, 647, 372)
# Hands Keypoint
# (532, 244, 638, 378)
# Hands Keypoint
# (521, 244, 627, 381)
# Hands Keypoint
# (504, 245, 609, 383)
# Hands Keypoint
# (489, 247, 589, 385)
# Hands Keypoint
# (469, 249, 565, 388)
# Hands Keypoint
# (450, 252, 546, 385)
# Hands Keypoint
# (433, 254, 528, 382)
# Hands Keypoint
# (419, 255, 509, 382)
# Hands Keypoint
# (406, 257, 492, 380)
# Hands Keypoint
# (394, 259, 477, 382)
# Hands Keypoint
# (386, 260, 465, 382)
# Hands Keypoint
# (379, 261, 459, 382)
# Hands Keypoint
# (374, 262, 453, 383)
# Hands Keypoint
# (373, 263, 450, 383)
# Hands Keypoint
# (373, 264, 450, 384)
# Hands Keypoint
# (375, 264, 452, 384)
# Hands Keypoint
# (377, 265, 455, 384)
# Hands Keypoint
# (381, 264, 459, 385)
# Hands Keypoint
# (385, 264, 464, 385)
# Hands Keypoint
# (390, 265, 469, 387)
# Hands Keypoint
# (396, 266, 476, 389)
# Hands Keypoint
# (407, 276, 484, 392)
# Hands Keypoint
# (414, 286, 489, 391)
# Hands Keypoint
# (422, 294, 494, 390)
# Hands Keypoint
# (428, 299, 496, 389)
# Hands Keypoint
# (432, 298, 499, 386)
# Hands Keypoint
# (433, 299, 500, 386)
# Hands Keypoint
# (434, 298, 500, 385)
# Hands Keypoint
# (433, 299, 501, 386)
# Hands Keypoint
# (431, 297, 501, 386)
# Hands Keypoint
# (427, 291, 500, 387)
# Hands Keypoint
# (420, 280, 498, 390)
# Hands Keypoint
# (416, 271, 499, 391)
# Hands Keypoint
# (415, 269, 501, 393)
# Hands Keypoint
# (415, 270, 501, 394)
# Hands Keypoint
# (418, 271, 503, 394)
# Hands Keypoint
# (422, 271, 504, 394)
# Hands Keypoint
# (425, 272, 505, 394)
# Hands Keypoint
# (436, 270, 508, 393)
# Hands Keypoint
# (436, 268, 512, 393)
# Hands Keypoint
# (435, 268, 514, 392)
# Hands Keypoint
# (433, 272, 510, 393)
# Hands Keypoint
# (426, 288, 510, 395)
# Hands Keypoint
# (425, 301, 513, 398)
# Hands Keypoint
# (420, 326, 516, 399)
# Hands Keypoint
# (414, 346, 470, 404)
# Hands Keypoint
# (433, 333, 509, 389)
# Hands Keypoint
# (415, 331, 481, 400)
# Hands Keypoint
# (437, 335, 514, 394)
# Hands Keypoint
# (420, 340, 486, 408)
# Hands Keypoint
# (439, 339, 521, 399)
# Hands Keypoint
# (421, 345, 503, 417)
# Hands Keypoint
# (447, 330, 535, 406)
# Hands Keypoint
# (463, 322, 550, 416)
# Hands Keypoint
# (475, 322, 562, 426)
# Hands Keypoint
# (486, 332, 566, 443)
# Hands Keypoint
# (242, 431, 288, 470)
# Hands Keypoint
# (243, 433, 290, 473)
# Hands Keypoint
# (245, 432, 291, 471)
# Hands Keypoint
# (245, 429, 293, 469)
# Hands Keypoint
# (85, 316, 291, 467)
# Hands Keypoint
# (261, 405, 306, 445)
# Hands Keypoint
# (255, 404, 305, 447)
# Hands Keypoint
# (252, 404, 304, 445)
# Hands Keypoint
# (257, 405, 306, 449)
# Hands Keypoint
# (258, 406, 307, 447)
# Hands Keypoint
# (261, 424, 292, 479)
# Hands Keypoint
# (259, 425, 291, 471)
# Hands Keypoint
# (256, 426, 288, 468)
# Hands Keypoint
# (254, 424, 287, 467)
# Hands Keypoint
# (256, 420, 286, 459)
# Hands Keypoint
# (254, 420, 287, 456)
# Hands Keypoint
# (254, 417, 290, 450)
# Hands Keypoint
# (258, 415, 296, 448)
# Hands Keypoint
# (267, 408, 304, 442)
# Hands Keypoint
# (201, 373, 309, 444)
# Hands Keypoint
# (216, 299, 314, 379)
# Hands Keypoint
# (135, 428, 228, 488)
# Hands Keypoint
# (126, 430, 214, 488)
# Hands Keypoint
# (130, 416, 212, 471)
# Hands Keypoint
# (130, 409, 222, 472)
# Hands Keypoint
# (129, 408, 223, 472)
# Hands Keypoint
# (130, 405, 228, 470)
# Hands Keypoint
# (128, 406, 228, 472)
# Hands Keypoint
# (127, 409, 226, 475)
# Hands Keypoint
# (126, 411, 226, 476)
# Hands Keypoint
# (125, 413, 225, 477)
# Hands Keypoint
# (124, 411, 222, 476)
# Hands Keypoint
# (122, 413, 221, 477)
# Hands Keypoint
# (120, 415, 219, 480)
# Hands Keypoint
# (118, 417, 215, 482)
# Hands Keypoint
# (115, 419, 215, 483)
# Hands Keypoint
# (116, 422, 215, 483)
# Hands Keypoint
# (115, 422, 213, 485)
# Hands Keypoint
# (115, 422, 215, 486)
# Hands Keypoint
# (116, 423, 216, 487)
# Hands Keypoint
# (116, 421, 217, 486)
# Hands Keypoint
# (117, 422, 218, 484)
# Hands Keypoint
# (118, 421, 219, 487)
# Hands Keypoint
# (118, 421, 220, 484)
# Hands Keypoint
# (118, 422, 219, 486)
# Hands Keypoint
# (117, 423, 218, 485)
# Hands Keypoint
# (117, 424, 217, 489)
# Hands Keypoint
# (116, 425, 218, 496)
# Hands Keypoint
# (116, 427, 217, 493)
# Hands Keypoint
# (116, 427, 217, 492)
# Hands Keypoint
# (116, 427, 217, 492)
# Hands Keypoint
# (117, 429, 218, 493)
# Hands Keypoint
# (116, 430, 216, 492)
# Hands Keypoint
# (116, 431, 218, 509)
# Hands Keypoint
# (115, 430, 215, 510)
# Hands Keypoint
# (115, 431, 216, 508)
# Hands Keypoint
# (114, 432, 215, 510)
# Hands Keypoint
# (112, 433, 212, 510)
# Hands Keypoint
# (113, 432, 214, 505)
# Hands Keypoint
# (112, 432, 212, 509)
# Hands Keypoint
# (112, 432, 214, 509)
# Hands Keypoint
# (113, 428, 215, 509)
# Hands Keypoint
# (114, 426, 218, 504)
# Hands Keypoint
# (116, 425, 220, 497)
# Hands Keypoint
# (120, 422, 223, 491)
# Hands Keypoint
# (117, 420, 222, 498)
# Hands Keypoint
# (118, 421, 222, 499)
# Hands Keypoint
# (117, 422, 221, 501)
# Hands Keypoint
# (116, 423, 220, 507)
# Hands Keypoint
# (118, 424, 222, 511)
# Hands Keypoint
# (117, 424, 222, 511)
# Hands Keypoint
# (115, 424, 221, 510)
# Hands Keypoint
# (115, 424, 219, 514)
# Hands Keypoint
# (108, 419, 216, 510)
# Hands Keypoint
# (103, 392, 202, 473)
# Hands Keypoint
# (317, 315, 346, 355)
# Hands Keypoint
# (314, 311, 342, 351)
# Hands Keypoint
# (310, 299, 342, 345)
# Hands Keypoint
# (304, 269, 355, 335)
# Hands Keypoint
# (308, 278, 355, 329)
# Hands Keypoint
# (310, 237, 368, 306)
# Hands Keypoint
# (314, 252, 354, 316)
# Hands Keypoint
# (258, 269, 292, 331)
# Hands Keypoint
# (128, 276, 249, 362)
# Hands Keypoint
# (120, 286, 237, 367)
# Hands Keypoint
# (112, 286, 227, 381)
# Hands Keypoint
# (107, 290, 223, 379)
# Hands Keypoint
# (110, 285, 209, 374)
# Hands Keypoint
# (326, 336, 377, 361)
# Hands Keypoint
# (318, 335, 370, 357)
# Hands Keypoint
# (318, 330, 362, 351)
# Hands Keypoint
# (319, 327, 364, 348)
# Hands Keypoint
# (197, 78, 243, 148)
# Hands Keypoint
# (179, 76, 222, 158)
# Hands Keypoint
# (173, 69, 224, 159)
# Hands Keypoint
# (254, 406, 295, 441)
# Hands Keypoint
# (188, 106, 231, 189)
# Hands Keypoint
# (179, 108, 223, 194)
# Hands Keypoint
# (172, 91, 221, 184)
# Hands Keypoint
# (167, 77, 222, 172)
# Hands Keypoint
# (170, 83, 221, 171)
# Hands Keypoint
# (164, 87, 213, 174)
# Hands Keypoint
# (171, 98, 216, 184)
# Hands Keypoint
# (167, 110, 214, 194)
# Hands Keypoint
# (151, 190, 206, 276)
# Hands Keypoint
# (144, 200, 201, 283)
# Hands Keypoint
# (147, 209, 202, 285)
# Hands Keypoint
# (150, 214, 204, 287)
# Hands Keypoint
# (150, 221, 204, 290)
# Hands Keypoint
# (152, 228, 209, 292)
# Hands Keypoint
# (152, 238, 213, 297)
# Hands Keypoint
# (150, 237, 212, 297)
# Hands Keypoint
# (150, 238, 214, 299)
# Hands Keypoint
# (150, 238, 215, 300)
# Hands Keypoint
# (149, 236, 211, 298)
# Hands Keypoint
# (153, 235, 216, 299)
# Hands Keypoint
# (158, 231, 217, 305)
# Hands Keypoint
# (163, 224, 219, 300)
# Hands Keypoint
# (170, 219, 222, 298)
# Hands Keypoint
# (171, 215, 223, 297)
# Hands Keypoint
# (173, 215, 223, 297)
# Hands Keypoint
# (174, 220, 226, 300)
# Hands Keypoint
# (176, 221, 225, 300)
# Hands Keypoint
# (176, 221, 226, 303)
# Hands Keypoint
# (173, 222, 229, 300)
# Hands Keypoint
# (512, 332, 600, 398)
# Hands Keypoint
# (528, 322, 614, 395)
# Hands Keypoint
# (539, 315, 630, 402)
# Hands Keypoint
# (538, 323, 633, 408)
# Hands Keypoint
# (535, 329, 639, 410)
# Hands Keypoint
# (532, 331, 638, 410)
# Hands Keypoint
# (531, 333, 639, 410)
# Hands Keypoint
# (529, 335, 637, 409)
# Hands Keypoint
# (528, 338, 633, 409)
# Hands Keypoint
# (527, 340, 631, 408)
# Hands Keypoint
# (528, 339, 628, 408)
# Hands Keypoint
# (528, 340, 626, 409)
# Hands Keypoint
# (528, 339, 626, 408)
# Hands Keypoint
# (528, 338, 625, 409)
# Hands Keypoint
# (528, 338, 625, 408)
# Hands Keypoint
# (527, 339, 624, 409)
# Hands Keypoint
# (527, 339, 624, 409)
# Hands Keypoint
# (528, 341, 624, 410)
# Hands Keypoint
# (527, 341, 623, 409)
# Hands Keypoint
# (528, 341, 622, 409)
# Hands Keypoint
# (529, 341, 621, 407)
# Hands Keypoint
# (530, 340, 618, 406)
# Hands Keypoint
# (532, 339, 618, 404)
# Hands Keypoint
# (533, 339, 615, 404)
# Hands Keypoint
# (535, 338, 614, 404)
# Hands Keypoint
# (538, 337, 615, 403)
# Hands Keypoint
# (537, 337, 614, 404)
# Hands Keypoint
# (538, 337, 613, 403)
# Hands Keypoint
# (539, 336, 611, 404)
# Hands Keypoint
# (541, 336, 611, 404)
# Hands Keypoint
# (541, 336, 611, 405)
# Hands Keypoint
# (540, 335, 611, 405)
# Hands Keypoint
# (541, 334, 611, 404)
# Hands Keypoint
# (540, 332, 612, 403)
# Hands Keypoint
# (538, 330, 612, 402)
# Hands Keypoint
# (537, 331, 613, 404)
# Hands Keypoint
# (535, 333, 613, 405)
# Hands Keypoint
# (535, 335, 611, 405)
# Hands Keypoint
# (536, 339, 610, 407)
# Hands Keypoint
# (536, 339, 608, 407)
# Hands Keypoint
# (536, 339, 609, 406)
# Hands Keypoint
# (536, 339, 609, 407)
# Hands Keypoint
# (536, 339, 608, 407)
# Hands Keypoint
# (536, 340, 607, 406)
# Hands Keypoint
# (536, 340, 606, 406)
# Hands Keypoint
# (535, 340, 606, 405)
# Hands Keypoint
# (535, 342, 606, 405)
# Hands Keypoint
# (535, 342, 607, 405)
# Hands Keypoint
# (535, 342, 606, 405)
# Hands Keypoint
# (535, 343, 607, 406)
# Hands Keypoint
# (535, 342, 604, 404)
# Hands Keypoint
# (535, 342, 606, 404)
# Hands Keypoint
# (535, 342, 605, 405)
# Hands Keypoint
# (536, 342, 605, 406)
# Hands Keypoint
# (536, 343, 605, 406)
# Hands Keypoint
# (536, 344, 606, 407)
# Hands Keypoint
# (535, 342, 604, 406)
# Hands Keypoint
# (536, 340, 604, 405)
# Hands Keypoint
# (536, 338, 604, 404)
# Hands Keypoint
# (536, 338, 603, 404)
# Hands Keypoint
# (537, 337, 603, 404)
# Hands Keypoint
# (536, 337, 603, 406)
# Hands Keypoint
# (536, 339, 602, 407)
# Hands Keypoint
# (535, 339, 600, 407)
# Hands Keypoint
# (533, 343, 600, 406)
# Hands Keypoint
# (533, 343, 598, 405)
# Hands Keypoint
# (531, 345, 600, 409)
# Hands Keypoint
# (530, 344, 599, 409)
# Hands Keypoint
# (530, 343, 598, 408)
# Hands Keypoint
# (529, 345, 597, 407)
# Hands Keypoint
# (529, 346, 598, 408)
# Hands Keypoint
# (528, 347, 598, 407)
# Hands Keypoint
# (529, 345, 599, 408)
# Hands Keypoint
# (529, 348, 599, 408)
# Hands Keypoint
# (528, 349, 601, 408)
# Hands Keypoint
# (528, 348, 602, 409)
# Hands Keypoint
# (528, 347, 603, 408)
# Hands Keypoint
# (529, 348, 602, 407)
# Hands Keypoint
# (529, 346, 602, 407)
# Hands Keypoint
# (532, 345, 602, 404)
# Hands Keypoint
# (534, 343, 602, 406)
# Hands Keypoint
# (536, 342, 601, 406)
# Hands Keypoint
# (538, 342, 601, 405)
# Hands Keypoint
# (538, 342, 602, 407)
# Hands Keypoint
# (539, 342, 602, 408)
# Hands Keypoint
# (539, 342, 602, 409)
# Hands Keypoint
# (539, 342, 602, 409)
# Hands Keypoint
# (539, 342, 600, 407)
# Hands Keypoint
# (539, 342, 601, 406)
# Hands Keypoint
# (540, 341, 601, 405)
# Hands Keypoint
# (540, 342, 601, 406)
# Hands Keypoint
# (540, 341, 601, 405)
# Hands Keypoint
# (540, 341, 603, 406)
# Hands Keypoint
# (541, 341, 603, 406)
# Hands Keypoint
# (541, 341, 603, 406)
# Hands Keypoint
# (542, 341, 603, 406)
# Hands Keypoint
# (543, 341, 604, 406)
# Hands Keypoint
# (543, 340, 604, 407)
# Hands Keypoint
# (543, 340, 604, 406)
# Hands Keypoint
# (543, 339, 604, 406)
# Hands Keypoint
# (543, 338, 604, 407)
# Hands Keypoint
# (544, 338, 605, 407)
# Hands Keypoint
# (544, 338, 604, 407)
# Hands Keypoint
# (544, 337, 605, 407)
# Hands Keypoint
# (544, 337, 605, 406)
# Hands Keypoint
# (545, 336, 604, 406)
# Hands Keypoint
# (544, 335, 604, 405)
# Hands Keypoint
# (544, 336, 604, 406)
# Hands Keypoint
# (544, 336, 603, 406)
# Hands Keypoint
# (542, 337, 602, 406)
# Hands Keypoint
# (542, 339, 603, 408)
# Hands Keypoint
# (542, 339, 603, 408)
# Hands Keypoint
# (541, 339, 602, 408)
# Hands Keypoint
# (540, 340, 603, 410)
# Hands Keypoint
# (539, 341, 602, 409)
# Hands Keypoint
# (538, 342, 601, 408)
# Hands Keypoint
# (538, 342, 601, 409)
# Hands Keypoint
# (539, 341, 601, 408)
# Hands Keypoint
# (539, 341, 600, 407)
# Hands Keypoint
# (540, 339, 601, 406)
# Hands Keypoint
# (539, 338, 600, 407)
# Hands Keypoint
# (538, 337, 600, 408)
# Hands Keypoint
# (539, 337, 600, 409)
# Hands Keypoint
# (538, 338, 600, 409)
# Hands Keypoint
# (538, 338, 600, 409)
# Hands Keypoint
# (537, 338, 600, 410)
# Hands Keypoint
# (536, 337, 599, 409)
# Hands Keypoint
# (536, 337, 598, 409)
# Hands Keypoint
# (535, 337, 598, 410)
# Hands Keypoint
# (535, 338, 596, 409)
# Hands Keypoint
# (236, 318, 286, 353)
# Hands Keypoint
# (236, 292, 305, 342)
# Hands Keypoint
# (239, 290, 306, 336)
# Hands Keypoint
# (234, 286, 307, 333)
# Hands Keypoint
# (235, 288, 307, 330)
# Hands Keypoint
# (534, 340, 598, 409)
# Hands Keypoint
# (213, 268, 300, 329)
# Hands Keypoint
# (204, 285, 302, 336)
# Hands Keypoint
# (199, 295, 299, 343)
# Hands Keypoint
# (197, 301, 299, 348)
# Hands Keypoint
# (194, 301, 297, 349)
# Hands Keypoint
# (188, 305, 294, 355)
# Hands Keypoint
# (187, 306, 293, 357)
# Hands Keypoint
# (184, 306, 291, 360)
# Hands Keypoint
# (178, 306, 284, 363)
# Hands Keypoint
# (174, 307, 278, 365)
# Hands Keypoint
# (171, 314, 273, 370)
# Hands Keypoint
# (167, 318, 268, 372)
# Hands Keypoint
# (165, 321, 268, 373)
# Hands Keypoint
# (165, 321, 268, 374)
# Hands Keypoint
# (164, 321, 271, 374)
# Hands Keypoint
# (166, 320, 275, 373)
# Hands Keypoint
# (168, 319, 280, 373)
# Hands Keypoint
# (172, 318, 283, 371)
# Hands Keypoint
# (175, 301, 286, 355)
# Hands Keypoint
# (182, 286, 296, 347)
# Hands Keypoint
# (186, 272, 298, 340)
# Hands Keypoint
# (186, 266, 298, 338)
# Hands Keypoint
# (188, 270, 290, 341)
# Hands Keypoint
# (187, 298, 296, 355)
# Hands Keypoint
# (188, 307, 299, 362)
# Hands Keypoint
# (190, 310, 301, 363)
# Hands Keypoint
# (190, 307, 300, 357)
# Hands Keypoint
# (200, 297, 304, 344)
# Hands Keypoint
# (199, 266, 304, 326)
# Hands Keypoint
# (205, 246, 305, 319)
# Hands Keypoint
# (203, 242, 305, 319)
# Hands Keypoint
# (199, 270, 307, 331)
# Hands Keypoint
# (202, 264, 308, 347)
# Hands Keypoint
# (187, 294, 295, 360)
# Hands Keypoint
# (186, 291, 293, 358)
# Hands Keypoint
# (184, 294, 292, 358)
# Hands Keypoint
# (183, 297, 292, 360)
# Hands Keypoint
# (183, 298, 291, 360)
# Hands Keypoint
# (183, 300, 292, 359)
# Hands Keypoint
# (183, 302, 293, 359)
# Hands Keypoint
# (184, 304, 293, 359)
# Hands Keypoint
# (183, 299, 292, 356)
# Hands Keypoint
# (183, 294, 291, 353)
# Hands Keypoint
# (184, 301, 294, 356)
# Hands Keypoint
# (185, 309, 297, 363)
# Hands Keypoint
# (185, 312, 296, 364)
# Hands Keypoint
# (185, 312, 297, 366)
# Hands Keypoint
# (185, 314, 296, 367)
# Hands Keypoint
# (184, 315, 295, 370)
# Hands Keypoint
# (185, 316, 295, 370)
# Hands Keypoint
# (183, 315, 296, 370)
# Hands Keypoint
# (183, 307, 297, 359)
# Hands Keypoint
# (526, 346, 590, 406)
# Hands Keypoint
# (213, 269, 315, 316)
# Hands Keypoint
# (198, 242, 309, 299)
# Hands Keypoint
# (187, 232, 302, 294)
# Hands Keypoint
# (187, 235, 295, 290)
# Hands Keypoint
# (187, 241, 293, 298)
# Hands Keypoint
# (192, 257, 298, 315)
# Hands Keypoint
# (192, 272, 309, 321)
# Hands Keypoint
# (190, 281, 304, 328)
# Hands Keypoint
# (204, 284, 290, 336)
# Hands Keypoint
# (185, 275, 306, 346)
# Hands Keypoint
# (196, 290, 290, 343)
# Hands Keypoint
# (214, 271, 299, 339)
# Hands Keypoint
# (214, 275, 291, 342)
# Hands Keypoint
# (214, 264, 283, 309)
# Hands Keypoint
# (216, 277, 272, 307)
# Hands Keypoint
# (216, 269, 276, 306)
# Hands Keypoint
# (220, 272, 276, 305)
# Hands Keypoint
# (169, 307, 253, 360)
# Hands Keypoint
# (170, 309, 253, 360)
# Hands Keypoint
# (170, 308, 253, 359)
# Hands Keypoint
# (539, 365, 633, 448)
# Hands Keypoint
# (541, 366, 634, 450)
# Hands Keypoint
# (541, 367, 625, 449)
# Hands Keypoint
# (538, 367, 624, 448)
# Hands Keypoint
# (535, 367, 618, 447)
# Hands Keypoint
# (534, 365, 626, 448)
# Hands Keypoint
# (535, 366, 626, 451)
# Hands Keypoint
# (535, 365, 627, 450)
# Hands Keypoint
# (537, 364, 626, 451)
# Hands Keypoint
# (536, 365, 626, 450)
# Hands Keypoint
# (536, 357, 625, 449)
# Hands Keypoint
# (535, 364, 627, 452)
# Hands Keypoint
# (535, 361, 626, 450)
# Hands Keypoint
# (537, 367, 623, 451)
# Hands Keypoint
# (536, 367, 625, 450)
# Hands Keypoint
# (535, 366, 624, 450)
# Hands Keypoint
# (533, 362, 620, 445)
# Hands Keypoint
# (534, 361, 607, 436)
# Hands Keypoint
# (536, 349, 608, 431)
# Hands Keypoint
# (527, 338, 609, 430)
# Hands Keypoint
# (534, 333, 604, 419)
# Hands Keypoint
# (531, 319, 600, 404)
# Hands Keypoint
# (532, 323, 598, 402)
# Hands Keypoint
# (533, 329, 600, 403)
# Hands Keypoint
# (535, 336, 602, 406)
# Hands Keypoint
# (536, 343, 602, 409)
# Hands Keypoint
# (537, 348, 604, 411)
# Hands Keypoint
# (539, 349, 604, 411)
# Hands Keypoint
# (546, 351, 603, 411)
# Hands Keypoint
# (543, 349, 608, 409)
# Hands Keypoint
# (544, 349, 608, 408)
# Hands Keypoint
# (544, 349, 606, 407)
# Hands Keypoint
# (545, 348, 605, 406)
# Hands Keypoint
# (545, 348, 604, 404)
# Hands Keypoint
# (546, 347, 606, 404)
# Hands Keypoint
# (546, 348, 606, 404)
# Hands Keypoint
# (546, 348, 605, 404)
# Hands Keypoint
# (546, 348, 606, 403)
# Hands Keypoint
# (547, 347, 605, 403)
# Hands Keypoint
# (547, 347, 606, 402)
# Hands Keypoint
# (546, 347, 605, 402)
# Hands Keypoint
# (546, 347, 604, 401)
# Hands Keypoint
# (546, 349, 606, 402)
# Hands Keypoint
# (546, 349, 606, 402)
# Hands Keypoint
# (545, 349, 606, 402)
# Hands Keypoint
# (544, 349, 606, 401)
# Hands Keypoint
# (543, 350, 605, 402)
# Hands Keypoint
# (545, 349, 604, 402)
# Hands Keypoint
# (544, 351, 603, 400)
# Hands Keypoint
# (544, 350, 604, 405)
# Hands Keypoint
# (543, 349, 604, 401)
# Hands Keypoint
# (544, 349, 605, 407)
# Hands Keypoint
# (544, 349, 604, 401)
# Hands Keypoint
# (543, 350, 606, 402)
# Hands Keypoint
# (545, 349, 606, 403)
# Hands Keypoint
# (545, 348, 607, 404)
# Hands Keypoint
# (544, 348, 607, 404)
# Hands Keypoint
# (546, 347, 605, 402)
# Hands Keypoint
# (545, 346, 607, 401)
# Hands Keypoint
# (546, 346, 607, 402)
# Hands Keypoint
# (545, 346, 606, 404)
# Hands Keypoint
# (544, 345, 604, 405)
# Hands Keypoint
# (543, 346, 604, 406)
# Hands Keypoint
# (543, 348, 603, 407)
# Hands Keypoint
# (542, 349, 602, 407)
# Hands Keypoint
# (543, 348, 603, 407)
# Hands Keypoint
# (543, 347, 603, 408)
# Hands Keypoint
# (544, 349, 603, 409)
# Hands Keypoint
# (544, 346, 603, 408)
# Hands Keypoint
# (544, 347, 603, 410)
# Hands Keypoint
# (544, 347, 605, 410)
# Hands Keypoint
# (545, 345, 604, 411)
# Hands Keypoint
# (545, 345, 604, 410)
# Hands Keypoint
# (545, 348, 604, 410)
# Hands Keypoint
# (545, 348, 603, 408)
# Hands Keypoint
# (546, 347, 603, 407)
# Hands Keypoint
# (546, 346, 603, 407)
# Hands Keypoint
# (547, 346, 604, 407)
# Hands Keypoint
# (547, 345, 603, 407)
# Hands Keypoint
# (546, 342, 604, 406)
# Hands Keypoint
# (546, 342, 603, 407)
# Hands Keypoint
# (546, 339, 603, 406)
# Hands Keypoint
# (545, 342, 603, 408)
# Hands Keypoint
# (545, 339, 603, 407)
# Hands Keypoint
# (543, 339, 602, 407)
# Hands Keypoint
# (543, 340, 601, 408)
# Hands Keypoint
# (542, 341, 601, 408)
# Hands Keypoint
# (541, 343, 600, 409)
# Hands Keypoint
# (542, 345, 601, 409)
# Hands Keypoint
# (542, 347, 602, 409)
# Hands Keypoint
# (542, 346, 601, 408)
# Hands Keypoint
# (542, 346, 601, 407)
# Hands Keypoint
# (543, 345, 601, 409)
# Hands Keypoint
# (543, 347, 602, 410)
# Hands Keypoint
# (545, 346, 602, 409)
# Hands Keypoint
# (544, 348, 603, 410)
# Hands Keypoint
# (546, 348, 602, 409)
# Hands Keypoint
# (545, 348, 603, 409)
# Hands Keypoint
# (174, 294, 278, 351)
# Hands Keypoint
# (166, 296, 275, 357)
# Hands Keypoint
# (164, 300, 273, 357)
# Hands Keypoint
# (165, 304, 275, 359)
# Hands Keypoint
# (163, 308, 273, 358)
# Hands Keypoint
# (166, 304, 282, 361)
# Hands Keypoint
# (170, 309, 282, 363)
# Hands Keypoint
# (172, 297, 284, 365)
# Hands Keypoint
# (177, 281, 285, 367)
# Hands Keypoint
# (180, 295, 286, 369)
# Hands Keypoint
# (183, 294, 287, 370)
# Hands Keypoint
# (182, 280, 286, 370)
# Hands Keypoint
# (181, 314, 285, 369)
# Hands Keypoint
# (178, 318, 283, 368)
# Hands Keypoint
# (177, 286, 283, 369)
# Hands Keypoint
# (177, 302, 282, 371)
# Hands Keypoint
# (173, 316, 281, 370)
# Hands Keypoint
# (171, 309, 281, 366)
# Hands Keypoint
# (168, 308, 282, 365)
# Hands Keypoint
# (173, 302, 287, 357)
# Hands Keypoint
# (172, 296, 290, 337)
# Hands Keypoint
# (175, 272, 277, 321)
# Hands Keypoint
# (182, 251, 289, 313)
# Hands Keypoint
# (187, 277, 293, 312)
# Hands Keypoint
# (190, 290, 303, 337)
# Hands Keypoint
# (186, 283, 303, 337)
# Hands Keypoint
# (186, 285, 299, 334)
# Hands Keypoint
# (187, 277, 296, 327)
# Hands Keypoint
# (190, 267, 290, 316)
# Hands Keypoint
# (192, 250, 280, 302)
# Hands Keypoint
# (194, 238, 282, 296)
# Hands Keypoint
# (190, 228, 282, 284)
# Hands Keypoint
# (190, 227, 282, 285)
# Hands Keypoint
# (189, 234, 279, 294)
# Hands Keypoint
# (187, 241, 277, 296)
# Hands Keypoint
# (184, 246, 278, 301)
# Hands Keypoint
# (186, 246, 279, 300)
# Hands Keypoint
# (199, 278, 292, 324)
# Hands Keypoint
# (199, 282, 285, 330)
# Hands Keypoint
# (200, 278, 282, 332)
# Hands Keypoint
# (204, 275, 280, 333)
# Hands Keypoint
# (222, 123, 329, 190)
# Hands Keypoint
# (220, 139, 302, 209)
# Hands Keypoint
# (206, 278, 283, 332)
# Hands Keypoint
# (204, 281, 283, 334)
# Hands Keypoint
# (201, 298, 282, 333)
# Hands Keypoint
# (173, 294, 267, 357)
# Hands Keypoint
# (164, 295, 275, 356)
# Hands Keypoint
# (162, 297, 276, 360)
# Hands Keypoint
# (158, 306, 272, 365)
# Hands Keypoint
# (154, 310, 250, 370)
# Hands Keypoint
# (157, 310, 245, 370)
# Hands Keypoint
# (161, 311, 247, 371)
# Hands Keypoint
# (161, 310, 247, 370)
# Hands Keypoint
# (160, 310, 246, 373)
# Hands Keypoint
# (160, 310, 243, 371)
# Hands Keypoint
# (160, 309, 242, 367)
# Hands Keypoint
# (160, 308, 244, 365)
# Hands Keypoint
# (167, 305, 275, 352)
# Hands Keypoint
# (207, 319, 278, 351)
# Hands Keypoint
# (207, 320, 277, 351)
# Hands Keypoint
# (212, 327, 270, 350)
# Hands Keypoint
# (164, 227, 269, 286)
# Hands Keypoint
# (217, 312, 288, 344)
# Hands Keypoint
# (186, 287, 265, 339)
# Hands Keypoint
# (195, 280, 272, 326)
# Hands Keypoint
# (200, 259, 291, 310)
# Hands Keypoint
# (552, 352, 599, 417)
# Hands Keypoint
# (211, 302, 297, 353)
# Hands Keypoint
# (206, 286, 301, 353)
# Hands Keypoint
# (207, 273, 308, 349)
# Hands Keypoint
# (206, 264, 294, 353)
# Hands Keypoint
# (203, 309, 299, 363)
# Hands Keypoint
# (196, 290, 299, 347)
# Hands Keypoint
# (198, 270, 289, 355)
# Hands Keypoint
# (192, 319, 281, 369)
# Hands Keypoint
# (189, 321, 269, 370)
# Hands Keypoint
# (186, 319, 262, 368)
# Hands Keypoint
# (184, 316, 259, 366)
# Hands Keypoint
# (182, 315, 257, 365)
# Hands Keypoint
# (177, 312, 255, 366)
# Hands Keypoint
# (174, 313, 252, 367)
# Hands Keypoint
# (168, 311, 245, 367)
# Hands Keypoint
# (166, 313, 242, 366)
# Hands Keypoint
# (163, 315, 241, 364)
# Hands Keypoint
# (163, 312, 240, 363)
# Hands Keypoint
# (159, 311, 238, 363)
# Hands Keypoint
# (159, 314, 237, 364)
# Hands Keypoint
# (157, 312, 234, 364)
# Hands Keypoint
# (156, 312, 234, 364)
# Hands Keypoint
# (154, 313, 232, 364)
# Hands Keypoint
# (155, 311, 234, 364)
# Hands Keypoint
# (155, 312, 234, 364)
# Hands Keypoint
# (155, 314, 235, 366)
# Hands Keypoint
# (154, 317, 235, 370)
# Hands Keypoint
# (153, 324, 257, 376)
# Hands Keypoint
# (154, 324, 266, 382)
# Hands Keypoint
# (150, 324, 264, 383)
# Hands Keypoint
# (143, 320, 255, 379)
# Hands Keypoint
# (137, 310, 257, 375)
# Hands Keypoint
# (132, 297, 252, 373)
# Hands Keypoint
# (134, 303, 249, 374)
# Hands Keypoint
# (135, 297, 250, 379)
# Hands Keypoint
# (133, 312, 251, 378)
# Hands Keypoint
# (132, 314, 246, 379)
# Hands Keypoint
# (132, 320, 243, 378)
# Hands Keypoint
# (133, 323, 240, 376)
# Hands Keypoint
# (133, 324, 237, 376)
# Hands Keypoint
# (133, 325, 233, 378)
# Hands Keypoint
# (132, 324, 232, 376)
# Hands Keypoint
# (132, 326, 232, 378)
# Hands Keypoint
# (133, 325, 233, 379)
# Hands Keypoint
# (135, 327, 235, 382)
# Hands Keypoint
# (138, 327, 243, 383)
# Hands Keypoint
# (140, 326, 253, 384)
# Hands Keypoint
# (140, 326, 252, 382)
# Hands Keypoint
# (140, 326, 253, 382)
# Hands Keypoint
# (140, 328, 252, 383)
# Hands Keypoint
# (141, 327, 253, 381)
# Hands Keypoint
# (140, 326, 253, 385)
# Hands Keypoint
# (144, 296, 261, 382)
# Hands Keypoint
# (144, 301, 260, 377)
# Hands Keypoint
# (146, 301, 261, 376)
# Hands Keypoint
# (146, 302, 265, 375)
# Hands Keypoint
# (143, 302, 262, 374)
# Hands Keypoint
# (147, 299, 263, 376)
# Hands Keypoint
# (149, 298, 261, 378)
# Hands Keypoint
# (151, 300, 261, 381)
# Hands Keypoint
# (151, 302, 260, 384)
# Hands Keypoint
# (152, 302, 265, 385)
# Hands Keypoint
# (152, 302, 262, 376)
# Hands Keypoint
# (158, 299, 262, 367)
# Hands Keypoint
# (153, 321, 256, 356)
# Hands Keypoint
# (158, 301, 264, 341)
# Hands Keypoint
# (158, 300, 242, 352)
# Hands Keypoint
# (180, 317, 231, 354)
# Hands Keypoint
# (177, 313, 228, 356)
# Hands Keypoint
# (173, 316, 222, 363)
# Hands Keypoint
# (170, 316, 222, 363)
# Hands Keypoint
# (153, 315, 225, 367)
# Hands Keypoint
# (382, 312, 450, 423)
# Hands Keypoint
# (386, 312, 453, 426)
# Hands Keypoint
# (388, 313, 455, 427)
# Hands Keypoint
# (387, 313, 454, 426)
# Hands Keypoint
# (385, 314, 451, 426)
# Hands Keypoint
# (385, 331, 450, 424)
# Hands Keypoint
# (388, 340, 453, 423)
# Hands Keypoint
# (391, 340, 456, 420)
# Hands Keypoint
# (395, 341, 458, 420)
# Hands Keypoint
# (399, 340, 459, 420)
# Hands Keypoint
# (402, 340, 460, 418)
# Hands Keypoint
# (405, 340, 461, 418)
# Hands Keypoint
# (406, 341, 461, 418)
# Hands Keypoint
# (408, 342, 463, 417)
# Hands Keypoint
# (409, 343, 466, 417)
# Hands Keypoint
# (410, 344, 466, 416)
# Hands Keypoint
# (411, 345, 467, 416)
# Hands Keypoint
# (413, 345, 466, 416)
# Hands Keypoint
# (414, 346, 464, 417)
# Hands Keypoint
# (411, 346, 461, 418)
# Hands Keypoint
# (141, 341, 193, 391)
# Hands Keypoint
# (408, 345, 456, 418)
# Hands Keypoint
# (408, 345, 456, 418)
# Hands Keypoint
# (130, 354, 191, 387)
# Hands Keypoint
# (134, 347, 193, 381)
# Hands Keypoint
# (141, 334, 203, 374)
# Hands Keypoint
# (143, 335, 207, 377)
# Hands Keypoint
# (141, 339, 208, 379)
# Hands Keypoint
# (140, 340, 208, 379)
# Hands Keypoint
# (140, 340, 208, 381)
# Hands Keypoint
# (142, 340, 209, 381)
# Hands Keypoint
# (140, 338, 209, 378)
# Hands Keypoint
# (141, 339, 209, 380)
# Hands Keypoint
# (135, 339, 204, 382)
# Hands Keypoint
# (133, 341, 203, 381)
# Hands Keypoint
# (131, 338, 200, 382)
# Hands Keypoint
# (130, 341, 200, 383)
# Hands Keypoint
# (131, 340, 201, 382)
# Hands Keypoint
# (130, 341, 201, 380)
# Hands Keypoint
# (130, 339, 202, 382)
# Hands Keypoint
# (130, 338, 205, 383)
# Hands Keypoint
# (128, 339, 205, 387)
# Hands Keypoint
# (127, 337, 205, 386)
# Hands Keypoint
# (123, 337, 202, 387)
# Hands Keypoint
# (123, 338, 199, 384)
# Hands Keypoint
# (124, 335, 201, 379)
# Hands Keypoint
# (124, 333, 200, 376)
# Hands Keypoint
# (123, 332, 201, 375)
# Hands Keypoint
# (121, 332, 200, 374)
# Hands Keypoint
# (120, 331, 197, 374)
# Hands Keypoint
# (122, 332, 198, 374)
# Hands Keypoint
# (121, 330, 196, 380)
# Hands Keypoint
# (119, 330, 194, 377)
# Hands Keypoint
# (120, 332, 193, 380)
# Hands Keypoint
# (119, 331, 193, 377)
# Hands Keypoint
# (118, 333, 193, 380)
# Hands Keypoint
# (119, 332, 192, 377)
# Hands Keypoint
# (119, 332, 192, 375)
# Hands Keypoint
# (118, 333, 189, 377)
# Hands Keypoint
# (116, 334, 188, 375)
# Hands Keypoint
# (114, 336, 186, 382)
# Hands Keypoint
# (110, 337, 182, 383)
# Hands Keypoint
# (109, 339, 181, 385)
# Hands Keypoint
# (111, 340, 181, 378)
# Hands Keypoint
# (105, 340, 177, 386)
# Hands Keypoint
# (106, 339, 180, 387)
# Hands Keypoint
# (103, 340, 179, 387)
# Hands Keypoint
# (103, 341, 179, 388)
# Hands Keypoint
# (103, 341, 179, 386)
# Hands Keypoint
# (104, 341, 177, 386)
# Hands Keypoint
# (106, 341, 178, 386)
# Hands Keypoint
# (106, 340, 179, 382)
# Hands Keypoint
# (104, 342, 178, 387)
# Hands Keypoint
# (105, 342, 179, 386)
# Hands Keypoint
# (103, 341, 178, 388)
# Hands Keypoint
# (105, 341, 180, 389)
# Hands Keypoint
# (103, 341, 179, 389)
# Hands Keypoint
# (106, 340, 182, 389)
# Hands Keypoint
# (104, 340, 180, 389)
# Hands Keypoint
# (103, 340, 180, 390)
# Hands Keypoint
# (105, 340, 183, 389)
# Hands Keypoint
# (106, 341, 182, 389)
# Hands Keypoint
# (109, 341, 184, 389)
# Hands Keypoint
# (109, 339, 184, 390)
# Hands Keypoint
# (113, 339, 187, 388)
# Hands Keypoint
# (112, 338, 186, 387)
# Hands Keypoint
# (114, 336, 188, 386)
# Hands Keypoint
# (116, 336, 190, 387)
# Hands Keypoint
# (118, 334, 191, 387)
# Hands Keypoint
# (120, 331, 193, 385)
# Hands Keypoint
# (122, 332, 195, 381)
# Hands Keypoint
# (121, 331, 195, 380)
# Hands Keypoint
# (118, 333, 194, 382)
# Hands Keypoint
# (119, 332, 196, 383)
# Hands Keypoint
# (119, 331, 197, 384)
# Hands Keypoint
# (119, 331, 197, 385)
# Hands Keypoint
# (117, 330, 197, 385)
# Hands Keypoint
# (115, 332, 197, 385)
# Hands Keypoint
# (115, 331, 197, 382)
# Hands Keypoint
# (114, 331, 196, 381)
# Hands Keypoint
# (479, 381, 595, 426)
# Hands Keypoint
# (492, 374, 606, 431)
# Hands Keypoint
# (528, 361, 616, 409)
# Hands Keypoint
# (111, 332, 195, 383)
# Hands Keypoint
# (108, 334, 191, 382)
# Hands Keypoint
# (132, 337, 192, 383)
# Hands Keypoint
# (119, 338, 189, 382)
# Hands Keypoint
# (112, 333, 192, 382)
# Hands Keypoint
# (112, 335, 191, 382)
# Hands Keypoint
# (111, 336, 190, 383)
# Hands Keypoint
# (136, 341, 190, 381)
# Hands Keypoint
# (127, 340, 188, 384)
# Hands Keypoint
# (115, 339, 190, 387)
# Hands Keypoint
# (114, 340, 189, 384)
# Hands Keypoint
# (143, 345, 194, 383)
# Hands Keypoint
# (136, 341, 192, 389)
# Hands Keypoint
# (124, 342, 198, 386)
# Hands Keypoint
# (153, 346, 201, 379)
# Hands Keypoint
# (150, 341, 198, 377)
# Hands Keypoint
# (143, 341, 198, 383)
# Hands Keypoint
# (127, 337, 201, 388)
# Hands Keypoint
# (129, 337, 202, 389)
# Hands Keypoint
# (132, 336, 204, 386)
# Hands Keypoint
# (136, 336, 207, 385)
# Hands Keypoint
# (137, 336, 206, 385)
# Hands Keypoint
# (141, 336, 208, 383)
# Hands Keypoint
# (141, 334, 208, 381)
# Hands Keypoint
# (143, 334, 210, 379)
# Hands Keypoint
# (144, 333, 210, 379)
# Hands Keypoint
# (140, 334, 208, 377)
# Hands Keypoint
# (139, 334, 206, 375)
# Hands Keypoint
# (135, 336, 203, 377)
# Hands Keypoint
# (132, 337, 199, 378)
# Hands Keypoint
# (127, 335, 196, 377)
# Hands Keypoint
# (118, 338, 183, 378)
# Hands Keypoint
# (114, 340, 181, 380)
# Hands Keypoint
# (112, 340, 181, 379)
# Hands Keypoint
# (120, 342, 177, 379)
# Hands Keypoint
# (104, 339, 177, 381)
# Hands Keypoint
# (99, 343, 172, 382)
# Hands Keypoint
# (94, 344, 168, 383)
# Hands Keypoint
# (91, 344, 165, 384)
# Hands Keypoint
# (90, 343, 165, 384)
# Hands Keypoint
# (103, 345, 164, 383)
# Hands Keypoint
# (92, 344, 167, 386)
# Hands Keypoint
# (108, 347, 164, 384)
# Hands Keypoint
# (102, 343, 177, 382)
# Hands Keypoint
# (102, 343, 175, 384)
# Hands Keypoint
# (105, 344, 178, 385)
# Hands Keypoint
# (105, 345, 176, 386)
# Hands Keypoint
# (104, 346, 176, 387)
# Hands Keypoint
# (107, 346, 178, 387)
# Hands Keypoint
# (108, 346, 179, 387)
# Hands Keypoint
# (106, 346, 177, 388)
# Hands Keypoint
# (107, 347, 177, 388)
# Hands Keypoint
# (107, 348, 176, 389)
# Hands Keypoint
# (111, 350, 179, 388)
# Hands Keypoint
# (118, 347, 187, 387)
# Hands Keypoint
# (121, 345, 190, 386)
# Hands Keypoint
# (122, 345, 191, 388)
# Hands Keypoint
# (123, 346, 192, 388)
# Hands Keypoint
# (124, 346, 193, 386)
# Hands Keypoint
# (127, 346, 195, 386)
# Hands Keypoint
# (126, 344, 195, 384)
# Hands Keypoint
# (131, 345, 201, 384)
# Hands Keypoint
# (131, 337, 201, 385)
# Hands Keypoint
# (136, 321, 203, 386)
# Hands Keypoint
# (164, 311, 211, 361)
# Hands Keypoint
# (175, 327, 204, 364)
# Hands Keypoint
# (150, 320, 195, 372)
# Hands Keypoint
# (156, 338, 195, 370)
# Hands Keypoint
# (146, 319, 190, 373)
# Hands Keypoint
# (142, 322, 190, 368)
# Hands Keypoint
# (135, 322, 186, 369)
# Hands Keypoint
# (134, 321, 184, 372)
# Hands Keypoint
# (134, 322, 182, 369)
# Hands Keypoint
# (136, 323, 185, 373)
# Hands Keypoint
# (138, 328, 186, 369)
# Hands Keypoint
# (147, 330, 191, 364)
# Hands Keypoint
# (168, 227, 239, 270)
# Hands Keypoint
# (163, 233, 241, 280)
# Hands Keypoint
# (160, 231, 241, 279)
# Hands Keypoint
# (158, 224, 241, 274)
# Hands Keypoint
# (156, 203, 237, 267)
# Hands Keypoint
# (156, 203, 238, 270)
# Hands Keypoint
# (192, 274, 263, 328)
# Hands Keypoint
# (149, 325, 245, 368)
# Hands Keypoint
# (142, 327, 240, 373)
# Hands Keypoint
# (142, 327, 241, 373)
# Hands Keypoint
# (143, 324, 241, 370)
# Hands Keypoint
# (145, 321, 242, 361)
# Hands Keypoint
# (151, 295, 244, 344)
# Hands Keypoint
# (146, 287, 224, 326)
# Hands Keypoint
# (148, 243, 245, 317)
# Hands Keypoint
# (146, 243, 239, 318)
# Hands Keypoint
# (145, 253, 235, 326)
# Hands Keypoint
# (166, 272, 220, 313)
# Hands Keypoint
# (140, 328, 238, 374)
# Hands Keypoint
# (138, 328, 237, 377)
# Hands Keypoint
# (140, 330, 239, 378)
# Hands Keypoint
# (140, 327, 240, 377)
# Hands Keypoint
# (146, 287, 231, 338)
# Hands Keypoint
# (143, 286, 245, 330)
# Hands Keypoint
# (136, 255, 235, 327)
# Hands Keypoint
# (135, 248, 234, 325)
# Hands Keypoint
# (136, 242, 230, 323)
# Hands Keypoint
# (139, 252, 240, 325)
# Hands Keypoint
# (147, 322, 238, 379)
# Hands Keypoint
# (133, 316, 212, 359)
# Hands Keypoint
# (143, 305, 242, 343)
# Hands Keypoint
# (154, 276, 249, 341)
# Hands Keypoint
# (164, 294, 264, 347)
# Hands Keypoint
# (547, 276, 641, 408)
# Hands Keypoint
# (548, 275, 637, 408)
# Hands Keypoint
# (547, 277, 640, 410)
# Hands Keypoint
# (544, 278, 637, 410)
# Hands Keypoint
# (539, 286, 637, 413)
# Hands Keypoint
# (539, 286, 637, 414)
# Hands Keypoint
# (536, 290, 635, 415)
# Hands Keypoint
# (535, 291, 635, 415)
# Hands Keypoint
# (159, 294, 221, 338)
# Hands Keypoint
# (158, 281, 236, 337)
# Hands Keypoint
# (162, 289, 236, 333)
# Hands Keypoint
# (164, 300, 241, 335)
# Hands Keypoint
# (177, 281, 240, 340)
# Hands Keypoint
# (167, 287, 234, 354)
# Hands Keypoint
# (549, 307, 636, 412)
# Hands Keypoint
# (165, 287, 231, 335)
# Hands Keypoint
# (158, 286, 235, 339)
# Hands Keypoint
# (160, 287, 237, 336)
# Hands Keypoint
# (163, 290, 239, 335)
# Hands Keypoint
# (172, 310, 237, 351)
# Hands Keypoint
# (158, 293, 231, 346)
# Hands Keypoint
# (157, 294, 231, 346)
# Hands Keypoint
# (158, 294, 233, 343)
# Hands Keypoint
# (159, 292, 235, 343)
# Hands Keypoint
# (536, 291, 636, 411)
# Hands Keypoint
# (163, 288, 237, 363)
# Hands Keypoint
# (155, 314, 230, 356)
# Hands Keypoint
# (145, 313, 221, 376)
# Hands Keypoint
# (139, 313, 211, 385)
# Hands Keypoint
# (137, 315, 207, 393)
# Hands Keypoint
# (136, 314, 208, 396)
# Hands Keypoint
# (132, 315, 209, 398)
# Hands Keypoint
# (131, 312, 212, 396)
# Hands Keypoint
# (129, 313, 212, 395)
# Hands Keypoint
# (127, 313, 210, 391)
# Hands Keypoint
# (128, 314, 210, 389)
# Hands Keypoint
# (126, 314, 209, 387)
# Hands Keypoint
# (127, 315, 210, 381)
# Hands Keypoint
# (129, 313, 211, 379)
# Hands Keypoint
# (130, 314, 210, 376)
# Hands Keypoint
# (130, 314, 209, 379)
# Hands Keypoint
# (131, 318, 210, 380)
# Hands Keypoint
# (132, 319, 211, 378)
# Hands Keypoint
# (130, 321, 211, 378)
# Hands Keypoint
# (131, 320, 211, 379)
# Hands Keypoint
# (128, 320, 208, 379)
# Hands Keypoint
# (125, 324, 209, 375)
# Hands Keypoint
# (122, 328, 207, 386)
# Hands Keypoint
# (125, 326, 211, 392)
# Hands Keypoint
# (124, 326, 212, 396)
# Hands Keypoint
# (124, 325, 214, 394)
# Hands Keypoint
# (123, 326, 218, 397)
# Hands Keypoint
# (122, 327, 219, 399)
# Hands Keypoint
# (122, 327, 222, 401)
# Hands Keypoint
# (123, 326, 224, 402)
# Hands Keypoint
# (125, 325, 224, 402)
# Hands Keypoint
# (125, 324, 225, 402)
# Hands Keypoint
# (125, 325, 225, 401)
# Hands Keypoint
# (124, 326, 225, 401)
# Hands Keypoint
# (124, 329, 223, 401)
# Hands Keypoint
# (125, 327, 222, 401)
# Hands Keypoint
# (125, 328, 221, 400)
# Hands Keypoint
# (127, 331, 217, 387)
# Hands Keypoint
# (128, 331, 212, 381)
# Hands Keypoint
# (130, 330, 203, 381)
# Hands Keypoint
# (131, 330, 201, 380)
# Hands Keypoint
# (131, 331, 200, 386)
# Hands Keypoint
# (131, 330, 200, 389)
# Hands Keypoint
# (132, 328, 201, 389)
# Hands Keypoint
# (132, 328, 202, 389)
# Hands Keypoint
# (133, 333, 203, 389)
# Hands Keypoint
# (133, 330, 202, 393)
# Hands Keypoint
# (133, 331, 203, 391)
# Hands Keypoint
# (133, 329, 203, 392)
# Hands Keypoint
# (134, 331, 204, 391)
# Hands Keypoint
# (135, 331, 205, 391)
# Hands Keypoint
# (136, 330, 205, 391)
# Hands Keypoint
# (135, 333, 205, 391)
# Hands Keypoint
# (134, 330, 206, 390)
# Hands Keypoint
# (134, 331, 206, 390)
# Hands Keypoint
# (135, 331, 206, 390)
# Hands Keypoint
# (135, 330, 206, 389)
# Hands Keypoint
# (135, 329, 206, 389)
# Hands Keypoint
# (134, 329, 206, 389)
# Hands Keypoint
# (135, 329, 207, 390)
# Hands Keypoint
# (134, 331, 206, 390)
# Hands Keypoint
# (134, 330, 206, 389)
# Hands Keypoint
# (134, 331, 206, 389)
# Hands Keypoint
# (134, 333, 206, 389)
# Hands Keypoint
# (133, 330, 205, 389)
# Hands Keypoint
# (133, 332, 207, 389)
# Hands Keypoint
# (134, 334, 207, 389)
# Hands Keypoint
# (134, 334, 209, 389)
# Hands Keypoint
# (133, 331, 210, 389)
# Hands Keypoint
# (134, 329, 211, 384)
# Hands Keypoint
# (133, 331, 210, 385)
# Hands Keypoint
# (133, 332, 208, 387)
# Hands Keypoint
# (134, 335, 208, 391)
# Hands Keypoint
# (134, 336, 209, 397)
# Hands Keypoint
# (134, 336, 216, 399)
# Hands Keypoint
# (135, 334, 221, 403)
# Hands Keypoint
# (135, 337, 224, 406)
# Hands Keypoint
# (134, 338, 226, 407)
# Hands Keypoint
# (133, 339, 225, 413)
# Hands Keypoint
# (134, 341, 224, 411)
# Hands Keypoint
# (133, 341, 223, 409)
# Hands Keypoint
# (133, 339, 223, 408)
# Hands Keypoint
# (134, 339, 224, 404)
# Hands Keypoint
# (133, 339, 224, 402)
# Hands Keypoint
# (132, 338, 223, 402)
# Hands Keypoint
# (133, 339, 223, 400)
# Hands Keypoint
# (132, 335, 223, 398)
# Hands Keypoint
# (130, 333, 221, 393)
# Hands Keypoint
# (127, 334, 218, 394)
# Hands Keypoint
# (126, 338, 218, 395)
# Hands Keypoint
# (122, 340, 215, 398)
# Hands Keypoint
# (122, 339, 216, 397)
# Hands Keypoint
# (120, 340, 213, 398)
# Hands Keypoint
# (122, 340, 211, 400)
# Hands Keypoint
# (122, 341, 208, 401)
# Hands Keypoint
# (121, 341, 205, 401)
# Hands Keypoint
# (120, 341, 205, 401)
# Hands Keypoint
# (118, 341, 203, 399)
# Hands Keypoint
# (118, 341, 205, 400)
# Hands Keypoint
# (118, 342, 204, 400)
# Hands Keypoint
# (118, 342, 199, 401)
# Hands Keypoint
# (118, 343, 197, 401)
# Hands Keypoint
# (119, 343, 197, 401)
# Hands Keypoint
# (116, 342, 197, 400)
# Hands Keypoint
# (119, 342, 206, 399)
# Hands Keypoint
# (117, 342, 202, 399)
# Hands Keypoint
# (117, 342, 209, 396)
# Hands Keypoint
# (116, 336, 211, 395)
# Hands Keypoint
# (118, 341, 216, 394)
# Hands Keypoint
# (117, 337, 212, 394)
# Hands Keypoint
# (119, 341, 213, 394)
# Hands Keypoint
# (118, 342, 216, 394)
# Hands Keypoint
# (118, 339, 218, 393)
# Hands Keypoint
# (117, 340, 217, 393)
# Hands Keypoint
# (118, 339, 217, 393)
# Hands Keypoint
# (117, 339, 218, 394)
# Hands Keypoint
# (119, 340, 218, 394)
# Hands Keypoint
# (119, 341, 219, 394)
# Hands Keypoint
# (120, 341, 219, 393)
# Hands Keypoint
# (120, 341, 220, 394)
# Hands Keypoint
# (120, 342, 219, 394)
# Hands Keypoint
# (120, 342, 220, 393)
# Hands Keypoint
# (120, 342, 219, 394)
# Hands Keypoint
# (122, 343, 217, 393)
# Hands Keypoint
# (121, 343, 216, 393)
# ...
# Hands Keypoint
# (532, 324, 619, 419)
# Hands Keypoint
# (540, 329, 605, 423)
# Hands Keypoint
# (546, 309, 611, 416)
# Hands Keypoint
# (538, 306, 606, 417)
# Hands Keypoint
# (537, 312, 600, 416)
# Hands Keypoint
# (534, 330, 590, 420)
# Hands Keypoint
# (527, 332, 609, 417)
# Hands Keypoint
# (539, 338, 612, 426)
# Hands Keypoint
# (525, 335, 614, 433)
# Hands Keypoint
# (523, 334, 611, 434)
# Hands Keypoint
# (523, 341, 612, 433)
# Hands Keypoint
# (532, 344, 615, 432)
# Hands Keypoint
# (531, 334, 618, 423)
# Hands Keypoint
# (545, 330, 619, 418)
# Hands Keypoint
# (545, 318, 622, 411)
# Hands Keypoint
# (548, 316, 622, 404)
# Hands Keypoint
# (562, 323, 627, 404)
# Hands Keypoint
# (562, 315, 629, 402)
# Hands Keypoint
# (558, 314, 627, 403)
# Hands Keypoint
# (549, 323, 625, 408)
# Hands Keypoint
# (534, 335, 620, 425)
# Hands Keypoint
# (543, 355, 616, 438)
# Hands Keypoint
# (515, 377, 623, 451)
# Hands Keypoint
# (512, 383, 630, 465)
# Hands Keypoint
# (513, 379, 631, 463)
# Hands Keypoint
# (520, 374, 617, 461)
# Hands Keypoint
# (523, 368, 612, 459)
# Hands Keypoint
# (519, 367, 613, 456)
# Hands Keypoint
# (518, 365, 612, 455)
# Hands Keypoint
# (517, 363, 611, 453)
# Hands Keypoint
# (515, 361, 610, 450)
# Hands Keypoint
# (511, 357, 612, 445)
# Hands Keypoint
# (507, 351, 615, 442)
# Hands Keypoint
# (510, 346, 614, 437)
# Hands Keypoint
# (512, 345, 619, 436)
# Hands Keypoint
# (514, 342, 619, 432)
# Hands Keypoint
# (516, 341, 619, 430)
# Hands Keypoint
# (518, 341, 617, 430)
# Hands Keypoint
# (516, 341, 616, 431)
# Hands Keypoint
# (516, 342, 618, 430)
# Hands Keypoint
# (516, 340, 619, 429)
# Hands Keypoint
# (516, 341, 617, 430)
# Hands Keypoint
# (517, 340, 619, 430)
# Hands Keypoint
# (516, 340, 617, 428)
# Hands Keypoint
# (517, 341, 618, 432)
# Hands Keypoint
# (516, 340, 617, 431)
# Hands Keypoint
# (515, 340, 617, 430)
# Hands Keypoint
# (516, 340, 617, 430)
# Hands Keypoint
# (516, 341, 617, 430)
# Hands Keypoint
# (516, 340, 620, 430)
# Hands Keypoint
# (517, 339, 618, 429)
# Hands Keypoint
# (516, 340, 616, 430)
# Hands Keypoint
# (515, 341, 615, 432)
# Hands Keypoint
# (515, 339, 615, 432)
# Hands Keypoint
# (511, 336, 613, 432)
# Hands Keypoint
# (500, 346, 598, 437)
# Hands Keypoint
# (496, 347, 593, 439)
# Hands Keypoint
# (495, 348, 589, 438)
# Hands Keypoint
# (493, 350, 586, 437)
# Hands Keypoint
# (489, 354, 584, 442)
# Hands Keypoint
# (482, 358, 580, 443)
# Hands Keypoint
# (482, 359, 580, 442)
# Hands Keypoint
# (494, 355, 592, 437)
# Hands Keypoint
# (496, 355, 591, 438)
# Hands Keypoint
# (495, 354, 592, 438)
# Hands Keypoint
# (496, 354, 592, 439)
# Hands Keypoint
# (496, 353, 595, 438)
# Hands Keypoint
# (497, 354, 590, 440)
# Hands Keypoint
# (495, 354, 590, 439)
# Hands Keypoint
# (494, 355, 588, 439)
# Hands Keypoint
# (494, 355, 587, 439)
# Hands Keypoint
# (494, 356, 589, 440)
# Hands Keypoint
# (495, 354, 588, 439)
# Hands Keypoint
# (500, 350, 591, 438)
# Hands Keypoint
# (509, 343, 596, 434)
# Hands Keypoint
# (514, 339, 604, 428)
# Hands Keypoint
# (516, 336, 606, 425)
# Hands Keypoint
# (518, 336, 615, 425)
# Hands Keypoint
# (518, 333, 616, 423)
# Hands Keypoint
# (515, 326, 615, 424)
# Hands Keypoint
# (506, 300, 618, 418)
# Hands Keypoint
# (501, 292, 624, 416)
# Hands Keypoint
# (503, 294, 623, 421)
# Hands Keypoint
# (499, 301, 625, 426)
# Hands Keypoint
# (498, 305, 627, 428)
# Hands Keypoint
# (501, 304, 628, 428)
# Hands Keypoint
# (503, 303, 628, 425)
# Hands Keypoint
# (503, 303, 629, 425)
# Hands Keypoint
# (502, 303, 629, 425)
# Hands Keypoint
# (502, 303, 627, 424)
# Hands Keypoint
# (501, 304, 627, 427)
# Hands Keypoint
# (501, 304, 626, 424)
# Hands Keypoint
# (501, 303, 625, 429)
# Hands Keypoint
# (501, 305, 624, 428)
# Hands Keypoint
# (499, 306, 622, 429)
# Hands Keypoint
# (498, 308, 619, 433)
# Hands Keypoint
# (496, 312, 620, 431)
# Hands Keypoint
# (497, 312, 619, 429)
# Hands Keypoint
# (497, 311, 618, 433)
# Hands Keypoint
# (497, 310, 618, 434)
# Hands Keypoint
# (498, 310, 613, 432)
# Hands Keypoint
# (498, 311, 611, 433)
# Hands Keypoint
# (497, 310, 610, 437)
# Hands Keypoint
# (497, 310, 610, 433)
# Hands Keypoint
# (496, 309, 609, 434)
# Hands Keypoint
# (498, 308, 600, 437)
# Hands Keypoint
# (507, 309, 594, 433)
# Hands Keypoint
# (518, 312, 593, 433)
# Hands Keypoint
# (526, 320, 592, 429)
# Hands Keypoint
# (529, 328, 594, 430)
# Hands Keypoint
# (535, 326, 596, 430)
# Hands Keypoint
# (539, 325, 598, 429)
# Hands Keypoint
# (540, 324, 596, 430)
# Hands Keypoint
# (542, 325, 597, 430)
# Hands Keypoint
# (541, 326, 597, 431)
# Hands Keypoint
# (539, 326, 597, 430)
# Hands Keypoint
# (537, 325, 595, 430)
# Hands Keypoint
# (536, 324, 595, 431)
# Hands Keypoint
# (538, 325, 597, 431)
# Hands Keypoint
# (539, 321, 597, 428)
# Hands Keypoint
# (534, 314, 596, 427)
# Hands Keypoint
# (529, 307, 590, 426)
# Hands Keypoint
# (522, 308, 586, 427)
# Hands Keypoint
# (515, 304, 582, 428)
# Hands Keypoint
# (504, 302, 572, 431)
# Hands Keypoint
# (500, 303, 569, 430)
# Hands Keypoint
# (497, 303, 567, 429)
# Hands Keypoint
# (497, 303, 569, 430)
# Hands Keypoint
# (498, 304, 565, 430)
# Hands Keypoint
# (495, 306, 566, 432)
# Hands Keypoint
# (492, 307, 562, 435)
# Hands Keypoint
# (487, 307, 561, 434)
# Hands Keypoint
# (484, 310, 559, 435)
# Hands Keypoint
# (487, 318, 561, 436)
# Hands Keypoint
# (491, 331, 563, 433)
# Hands Keypoint
# (497, 334, 568, 432)
# Hands Keypoint
# (500, 339, 569, 432)
# Hands Keypoint
# (500, 340, 569, 431)
# Hands Keypoint
# (500, 340, 568, 431)
# Hands Keypoint
# (498, 340, 568, 431)
# Hands Keypoint
# (498, 341, 569, 433)
# Hands Keypoint
# (498, 342, 571, 435)
# Hands Keypoint
# (500, 341, 571, 434)
# Hands Keypoint
# (502, 339, 574, 433)
# Hands Keypoint
# (504, 337, 576, 433)
# Hands Keypoint
# (504, 337, 577, 433)
# Hands Keypoint
# (504, 337, 578, 433)
# Hands Keypoint
# (505, 337, 577, 433)
# Hands Keypoint
# (504, 338, 577, 433)
# Hands Keypoint
# (505, 338, 576, 433)
# Hands Keypoint
# (504, 338, 576, 436)
# Hands Keypoint
# (504, 339, 576, 435)
# Hands Keypoint
# (505, 340, 576, 437)
# Hands Keypoint
# (505, 340, 575, 438)
# Hands Keypoint
# (505, 339, 575, 437)
# Hands Keypoint
# (506, 340, 575, 437)
# Hands Keypoint
# (505, 341, 575, 437)
# Hands Keypoint
# (505, 342, 573, 438)
# Hands Keypoint
# (507, 344, 573, 439)
# Hands Keypoint
# (507, 346, 574, 440)
# Hands Keypoint
# (507, 347, 573, 438)
# Hands Keypoint
# (506, 348, 574, 438)
# Hands Keypoint
# (507, 349, 574, 437)
# Hands Keypoint
# (508, 350, 573, 436)
# Hands Keypoint
# (507, 350, 574, 435)
# Hands Keypoint
# (508, 352, 572, 434)
# Hands Keypoint
# (507, 353, 572, 435)
# Hands Keypoint
# (507, 352, 569, 433)
# Hands Keypoint
# (504, 354, 569, 434)
# Hands Keypoint
# (502, 353, 568, 435)
# Hands Keypoint
# (502, 355, 568, 434)
# Hands Keypoint
# (500, 355, 566, 434)
# Hands Keypoint
# (500, 357, 567, 435)
# Hands Keypoint
# (502, 357, 567, 435)
# Hands Keypoint
# (502, 356, 568, 432)
# Hands Keypoint
# (506, 351, 573, 426)
# Hands Keypoint
# (513, 348, 586, 422)
# Hands Keypoint
# (61, 335, 150, 389)
# Hands Keypoint
# (64, 335, 150, 389)
# Hands Keypoint
# (63, 334, 150, 388)
# Hands Keypoint
# (62, 334, 150, 388)
# Hands Keypoint
# (63, 335, 151, 388)
# Hands Keypoint
# (62, 333, 151, 387)
# Hands Keypoint
# (63, 334, 153, 388)
# Hands Keypoint
# (65, 335, 150, 388)
# Hands Keypoint
# (67, 335, 151, 387)
# Hands Keypoint
# (68, 335, 150, 388)
# Hands Keypoint
# (66, 335, 153, 389)
# Hands Keypoint
# (66, 335, 150, 387)
# Hands Keypoint
# (66, 335, 149, 388)
# Hands Keypoint
# (63, 335, 149, 387)
# Hands Keypoint
# (62, 335, 149, 388)
# Hands Keypoint
# (63, 336, 147, 388)
# Hands Keypoint
# (61, 336, 149, 388)
# Hands Keypoint
# (60, 335, 144, 387)
# Hands Keypoint
# (60, 337, 144, 390)
# Hands Keypoint
# (61, 338, 148, 389)
# Hands Keypoint
# (61, 337, 147, 390)
# Hands Keypoint
# (337, 379, 416, 449)
# Hands Keypoint
# (328, 361, 409, 451)
# Hands Keypoint
# (321, 359, 400, 452)
# Hands Keypoint
# (60, 337, 145, 389)
# Hands Keypoint
# (58, 337, 148, 389)
# Hands Keypoint
# (58, 336, 152, 390)
# Hands Keypoint
# (60, 337, 151, 389)
# Hands Keypoint
# (59, 337, 155, 389)
# Hands Keypoint
# (61, 338, 153, 390)
# Hands Keypoint
# (62, 338, 154, 389)
# Hands Keypoint
# (62, 337, 153, 389)
# Hands Keypoint
# (61, 339, 149, 389)
# Hands Keypoint
# (61, 341, 139, 393)
# Hands Keypoint
# (59, 341, 138, 393)
# Hands Keypoint
# (59, 342, 136, 394)
# Hands Keypoint
# (57, 342, 139, 394)
# Hands Keypoint
# (59, 342, 139, 394)
# Hands Keypoint
# (58, 342, 144, 394)
# Hands Keypoint
# (59, 342, 138, 395)
# Hands Keypoint
# (60, 341, 145, 394)
# Hands Keypoint
# (61, 342, 139, 395)
# Hands Keypoint
# (61, 342, 139, 394)
# Hands Keypoint
# (58, 343, 136, 395)
# Hands Keypoint
# (57, 343, 134, 396)
# Hands Keypoint
# (57, 345, 133, 397)
# Hands Keypoint
# (53, 345, 127, 397)
# Hands Keypoint
# (53, 344, 126, 398)
# Hands Keypoint
# (52, 346, 127, 398)
# Hands Keypoint
# (50, 345, 125, 398)
# Hands Keypoint
# (48, 345, 127, 398)
# Hands Keypoint
# (131, 348, 157, 395)
# Hands Keypoint
# (129, 345, 156, 393)
# Hands Keypoint
# (124, 350, 154, 396)
# Hands Keypoint
# (45, 344, 125, 402)
# Hands Keypoint
# (43, 344, 123, 403)
# Hands Keypoint
# (41, 345, 125, 400)
# Hands Keypoint
# (42, 342, 123, 397)
# Hands Keypoint
# (41, 341, 126, 397)
# Hands Keypoint
# (111, 351, 152, 407)
# Hands Keypoint
# (115, 352, 151, 404)
# Hands Keypoint
# (107, 355, 150, 403)
# Hands Keypoint
# (107, 359, 146, 403)
# Hands Keypoint
# (104, 364, 142, 405)
# Hands Keypoint
# (99, 365, 135, 400)
# Hands Keypoint
# (102, 368, 134, 402)
# Hands Keypoint
# (10, 346, 100, 397)
# Hands Keypoint
# (91, 369, 126, 405)
# Hands Keypoint
# (104, 366, 127, 401)
# Hands Keypoint
# (3, 351, 91, 402)
# Hands Keypoint
# (1, 353, 89, 402)
# Hands Keypoint
# (83, 350, 129, 410)
# Hands Keypoint
# (76, 356, 123, 405)
# Hands Keypoint
# (73, 361, 116, 404)
# Hands Keypoint
# (64, 358, 110, 398)
# Hands Keypoint
# (17, 340, 92, 403)
# Hands Keypoint
# (201, 394, 288, 521)
# Hands Keypoint
# (195, 386, 290, 505)
# Hands Keypoint
# (176, 400, 269, 496)
# Hands Keypoint
# (169, 409, 248, 497)
# Hands Keypoint
# (4, 342, 69, 417)
# Hands Keypoint
# (10, 335, 80, 411)
# Hands Keypoint
# (17, 331, 88, 402)
# Hands Keypoint
# (18, 326, 88, 397)
# Hands Keypoint
# (24, 319, 93, 389)
# Hands Keypoint
# (37, 320, 94, 378)
# Hands Keypoint
# (32, 320, 95, 368)
# Hands Keypoint
# (-20, 301, 88, 380)
# Hands Keypoint
# (-33, 295, 88, 372)
# Hands Keypoint
# (23, 332, 83, 439)
# Hands Keypoint
# (16, 335, 73, 440)
# Hands Keypoint
# (8, 339, 75, 446)
# Hands Keypoint
# (-3, 340, 67, 442)
# Hands Keypoint
# (-7, 344, 65, 438)
# Hands Keypoint
# (2, 338, 70, 420)
# Hands Keypoint
# (1, 331, 71, 411)
# Hands Keypoint
# (8, 327, 68, 396)
# Hands Keypoint
# (14, 327, 66, 399)
# Hands Keypoint
# (25, 331, 85, 425)
# Hands Keypoint
# (27, 334, 81, 419)
# Hands Keypoint
# (33, 335, 90, 423)
# Hands Keypoint
# (33, 335, 95, 427)
# Hands Keypoint
# (36, 335, 99, 438)
# Hands Keypoint
# (49, 341, 116, 416)
# Hands Keypoint
# (56, 338, 128, 443)
# Hands Keypoint
# (68, 342, 137, 435)
# Hands Keypoint
# (51, 349, 142, 445)
# Hands Keypoint
# (83, 347, 153, 438)
# Hands Keypoint
# (1, 373, 111, 460)
# Hands Keypoint
# (3, 369, 117, 459)
# Hands Keypoint
# (10, 371, 121, 459)
# Hands Keypoint
# (18, 373, 128, 459)
# Hands Keypoint
# (124, 353, 188, 438)
# Hands Keypoint
# (125, 353, 188, 432)
# Hands Keypoint
# (132, 353, 189, 430)
# Hands Keypoint
# (50, 373, 161, 466)
# Hands Keypoint
# (142, 349, 202, 449)
# Hands Keypoint
# (142, 347, 196, 445)
# Hands Keypoint
# (146, 343, 199, 440)
# Hands Keypoint
# (149, 343, 200, 437)
# Hands Keypoint
# (151, 342, 201, 433)
# Hands Keypoint
# (150, 339, 202, 428)
# Hands Keypoint
# (153, 342, 203, 431)
# Hands Keypoint
# (153, 339, 201, 428)
# Hands Keypoint
# (153, 338, 203, 432)
# Hands Keypoint
# (157, 337, 206, 429)
# Hands Keypoint
# (161, 339, 211, 430)
# Hands Keypoint
# (165, 339, 212, 425)
# Hands Keypoint
# (166, 337, 218, 425)
# Hands Keypoint
# (171, 338, 216, 417)
# Hands Keypoint
# (180, 334, 220, 404)
# Hands Keypoint
# (102, 377, 211, 458)
# Hands Keypoint
# (402, 332, 543, 458)
# Hands Keypoint
# (448, 343, 560, 456)
# Hands Keypoint
# (468, 347, 580, 452)
# Hands Keypoint
# (128, 370, 222, 449)
# Hands Keypoint
# (134, 370, 224, 447)
# Hands Keypoint
# (145, 369, 232, 446)
# Hands Keypoint
# (149, 370, 234, 445)
# Hands Keypoint
# (153, 369, 237, 444)
# Hands Keypoint
# (156, 368, 240, 447)
# Hands Keypoint
# (160, 370, 244, 445)
# Hands Keypoint
# (162, 370, 246, 448)
# Hands Keypoint
# (166, 370, 249, 447)
# Hands Keypoint
# (165, 370, 249, 451)
# Hands Keypoint
# (165, 370, 248, 450)
# Hands Keypoint
# (169, 372, 250, 450)
# Hands Keypoint
# (171, 373, 248, 454)
# Hands Keypoint
# (173, 377, 252, 451)
# Hands Keypoint
# (168, 375, 248, 451)
# Hands Keypoint
# (168, 377, 247, 450)
# Hands Keypoint
# (167, 375, 244, 449)
# Hands Keypoint
# (167, 375, 243, 446)
# Hands Keypoint
# (165, 374, 241, 451)
# Hands Keypoint
# (164, 374, 240, 447)
# Hands Keypoint
# (163, 373, 241, 451)
# Hands Keypoint
# (163, 372, 241, 450)
# Hands Keypoint
# (165, 371, 243, 453)
# Hands Keypoint
# (165, 371, 244, 450)
# Hands Keypoint
# (163, 371, 243, 454)
# Hands Keypoint
# (164, 372, 246, 455)
# Hands Keypoint
# (168, 373, 250, 456)
# Hands Keypoint
# (168, 373, 248, 453)
# Hands Keypoint
# (170, 375, 250, 453)
# Hands Keypoint
# (169, 374, 250, 454)
# Hands Keypoint
# (172, 375, 252, 452)
# Hands Keypoint
# (172, 375, 255, 451)
# Hands Keypoint
# (172, 374, 255, 452)
# Hands Keypoint
# (172, 374, 256, 454)
# Hands Keypoint
# (168, 374, 252, 455)
# Hands Keypoint
# (166, 373, 248, 456)
# Hands Keypoint
# (164, 374, 247, 456)
# Hands Keypoint
# (156, 371, 236, 451)
# Hands Keypoint
# (150, 372, 229, 452)
# Hands Keypoint
# (143, 373, 220, 451)
# Hands Keypoint
# (211, 375, 260, 455)
# Hands Keypoint
# (198, 382, 256, 459)
# Hands Keypoint
# (195, 380, 258, 460)
# Hands Keypoint
# (194, 373, 253, 454)
# Hands Keypoint
# (187, 373, 246, 454)
# Hands Keypoint
# (185, 371, 239, 450)
# Hands Keypoint
# (187, 367, 242, 443)
# Hands Keypoint
# (186, 365, 233, 439)
# Hands Keypoint
# (178, 365, 229, 443)
# Hands Keypoint
# (180, 365, 223, 436)
# Hands Keypoint
# (176, 365, 220, 436)
# Hands Keypoint
# (174, 362, 215, 434)
# Hands Keypoint
# (95, 391, 177, 456)
# Hands Keypoint
# (173, 363, 209, 442)
# Hands Keypoint
# (175, 363, 213, 437)
# Hands Keypoint
# (180, 365, 219, 441)
# Hands Keypoint
# (186, 362, 227, 433)
# Hands Keypoint
# (195, 360, 237, 430)
# Hands Keypoint
# (130, 380, 204, 453)
# Hands Keypoint
# (133, 379, 205, 452)
# Hands Keypoint
# (135, 377, 205, 450)
# Hands Keypoint
# (137, 377, 205, 449)
# Hands Keypoint
# (136, 382, 204, 454)
# Hands Keypoint
# (129, 392, 195, 468)
# Hands Keypoint
# (5, 433, 90, 530)
# Hands Keypoint
# (7, 426, 91, 523)
# Hands Keypoint
# (6, 423, 86, 511)
# Hands Keypoint
# (4, 427, 77, 520)
# Hands Keypoint
# (3, 432, 66, 514)
# Hands Keypoint
# (217, 63, 414, 326)
# Hands Keypoint
# (171, 52, 397, 317)
# Hands Keypoint
# (214, 63, 382, 384)
# Hands Keypoint
# (295, 165, 441, 380)
# Hands Keypoint
# (297, 162, 485, 406)
# Hands Keypoint
# (128, 162, 352, 406)
# Hands Keypoint
# (121, 184, 348, 396)
# Hands Keypoint
# (157, 116, 403, 385)
# Hands Keypoint
# (207, 88, 262, 177)
# Hands Keypoint
# (214, 66, 245, 172)
# Hands Keypoint
# (217, 60, 240, 172)
# Hands Keypoint
# (297, 5, 409, 110)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 120
#     115             cv2.waitKey(1)
#     119 if __name__ == "__main__":
# --> 120             main()
#
# Cell In[1], line 102, in main()
#      99 while True:
#     100     ret, frame = cap.read()
# --> 102     frame = detector.findFingers(frame)
#     103     lmsList = detector.findPosition(frame)
#     104     # if len(lmsList)!=0:
#     105         #print(lmsList[0])
#
# Cell In[1], line 20, in HandTrackingDynamic.findFingers(self, frame, draw)
#      18 def findFingers(self, frame, draw=True):
#      19     imgRGB = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
# ---> 20     self.results = self.hands.process(imgRGB)
#      21     if self.results.multi_hand_landmarks:
#      22         for handLms in self.results.multi_hand_landmarks:
#
# File /usr/local/lib/python3.10/dist-packages/mediapipe/python/solutions/hands.py:153, in Hands.process(self, image)
#     132 def process(self, image: np.ndarray) -> NamedTuple:
#     133   """Processes an RGB image and returns the hand landmarks and handedness of each detected hand.
#     134
#     135   Args:
#    (...)
#     150          right hand) of the detected hand.
#     151   """
# --> 153   return super().process(input_data={'image': image})
#
# File /usr/local/lib/python3.10/dist-packages/mediapipe/python/solution_base.py:372, in SolutionBase.process(self, input_data)
#     366   else:
#     367     self._graph.add_packet_to_input_stream(
#     368         stream=stream_name,
#     369         packet=self._make_packet(input_stream_type,
#     370                                  data).at(self._simulated_timestamp))
# --> 372 self._graph.wait_until_idle()
#     373 # Create a NamedTuple object where the field names are mapping to the graph
#     374 # output stream names.
#     375 solution_outputs = collections.namedtuple(
#     376     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:
